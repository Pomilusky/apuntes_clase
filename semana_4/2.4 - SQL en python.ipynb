# %% [markdown]
# # 2.4 - SQL en python
#
# **Primero cargar datos...**

# %%
# cargar datos

import pandas as pd

df=pd.read_csv('data/shoes.csv')

df.head()
# Out:
#                      id             dateAdded           dateUpdated asins  \
# 0  AVpfEf_hLJeJML431ueH  2015-05-04T12:13:08Z  2018-01-29T04:38:43Z   NaN
# 1  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 2  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 3  AVpjXyCc1cnluZ0-V-Gj  2017-01-27T01:25:56Z  2018-01-04T11:52:35Z   NaN
# 4  AVphGKLPilAPnD_x1Nrm  2017-01-27T01:25:56Z  2018-01-18T03:55:18Z   NaN
#
#          brand                                         categories  \
# 0  Naturalizer  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 1     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 2     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 3     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 4     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
#
#   primaryCategories                          colors                 dimension  \
# ...

# %%
# seleccion de datos

df=df[['brand', 'colors', 'sizes', 'prices.amountMax', 'imageURLs', 'ean', 'upc']]
df.head()
# Out:
#          brand                          colors  \
# 0  Naturalizer  Silver,Cream Watercolor Floral
# 1     MUK LUKS                            Grey
# 2     MUK LUKS                            Grey
# 3     MUK LUKS                           Black
# 4     MUK LUKS                            Grey
#
#                                                sizes  prices.amountMax  \
# 0  6W,9W,7.5W,12W,8.5M,9N,9M,9.5M,10.5M,10W,8.5W,...             55.99
# 1                                         10,7,6,9,8             47.00
# 2                                         10,7,6,9,8             35.25
# 3                                         10,7,6,9,8             24.75
# 4                                         10,7,6,9,8             33.00
#
#                                            imageURLs           ean  \
# 0  https://i5.walmartimages.com/asr/861ca6cf-fa55...           NaN
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# ...

# %%
# quita nan

df=df.dropna().reset_index(drop=True)

df.head()
# Out:
#        brand       colors       sizes  prices.amountMax  \
# 0   MUK LUKS         Grey  10,7,6,9,8             47.00
# 1   MUK LUKS         Grey  10,7,6,9,8             35.25
# 2   MUK LUKS        Black  10,7,6,9,8             24.75
# 3   MUK LUKS         Grey  10,7,6,9,8             33.00
# 4  Soft Ones  Brown Tweed  5,6.5,9,11             14.00
#
#                                            imageURLs           ean  \
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 2  https://i5.walmartimages.com/asr/950d38a5-0113...  3.397705e+10
# 3  https://i5.walmartimages.com/asr/5e137bc3-c900...  3.397705e+10
# 4  https://i5.walmartimages.com/asr/7b979ba6-fa0a...  3.397705e+10
#
#             upc
# 0  033977045743
# 1  033977045743
# 2  033977045903
# 3  033977045958
# 4  033977052222

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664 entries, 0 to 663
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   brand             664 non-null    object
#  1   colors            664 non-null    object
#  2   sizes             664 non-null    object
#  3   prices.amountMax  664 non-null    float64
#  4   imageURLs         664 non-null    object
#  5   ean               664 non-null    float64
#  6   upc               664 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 1.4 MB

# %%
df.sizes=df.sizes.apply(lambda x: x.split(','))
df.colors=df.colors.apply(lambda x: x.split(','))

df.head()
# Out:
#        brand         colors             sizes  prices.amountMax  \
# 0   MUK LUKS         [Grey]  [10, 7, 6, 9, 8]             47.00
# 1   MUK LUKS         [Grey]  [10, 7, 6, 9, 8]             35.25
# 2   MUK LUKS        [Black]  [10, 7, 6, 9, 8]             24.75
# 3   MUK LUKS         [Grey]  [10, 7, 6, 9, 8]             33.00
# 4  Soft Ones  [Brown Tweed]   [5, 6.5, 9, 11]             14.00
#
#                                            imageURLs           ean  \
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 2  https://i5.walmartimages.com/asr/950d38a5-0113...  3.397705e+10
# 3  https://i5.walmartimages.com/asr/5e137bc3-c900...  3.397705e+10
# 4  https://i5.walmartimages.com/asr/7b979ba6-fa0a...  3.397705e+10
#
#             upc
# 0  033977045743
# 1  033977045743
# 2  033977045903
# 3  033977045958
# 4  033977052222

# %%
# un registro por cada talla y cada color

df=df.explode('sizes').reset_index(drop=True)
df=df.explode('colors').reset_index(drop=True)

df.head()
# Out:
#       brand colors sizes  prices.amountMax  \
# 0  MUK LUKS   Grey    10              47.0
# 1  MUK LUKS   Grey     7              47.0
# 2  MUK LUKS   Grey     6              47.0
# 3  MUK LUKS   Grey     9              47.0
# 4  MUK LUKS   Grey     8              47.0
#
#                                            imageURLs           ean  \
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 3  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 4  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
#
#             upc
# 0  033977045743
# 1  033977045743
# 2  033977045743
# 3  033977045743
# 4  033977045743

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   brand             41188 non-null  object
#  1   colors            41188 non-null  object
#  2   sizes             41188 non-null  object
#  3   prices.amountMax  41188 non-null  float64
#  4   imageURLs         41188 non-null  object
#  5   ean               41188 non-null  float64
#  6   upc               41188 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 94.7 MB

# %%
import warnings
warnings.simplefilter('ignore')

codigo=pd.read_csv('data/upc_corpus.csv')
codigo=codigo.dropna().reset_index(drop=True)

codigo.head()
# Out:
#             ean                                               name
# 0  725177540363  Belle and The Yank 1/4" - 20 TPI x 90mm Hex Dr...
# 1  725177540370  Belle and The Yank 1/4" - 20 TPI x 120mm Hex D...
# 2  797776092321       Eazel Wines 750ml Red Wine Eazel Shiraz 2014
# 3  701197194311  IsyLei lilla IsyLei All-In-One, lilla - Cono L...
# 4  797776110773                    MsConscious 370g Skinny Granola

# %%
codigo.shape
# Out:
# (1045885, 2)

# %%
df.ean=codigo.ean.iloc[0:len(df)]

# %%
# renombrar

df=df.rename(columns={'colors':'color', 
                      'sizes':'size', 
                      'prices.amountMax':'price', 
                      'imageURLs':'url'})

df.head()
# Out:
#       brand color size  price  \
# 0  MUK LUKS  Grey   10   47.0
# 1  MUK LUKS  Grey    7   47.0
# 2  MUK LUKS  Grey    6   47.0
# 3  MUK LUKS  Grey    9   47.0
# 4  MUK LUKS  Grey    8   47.0
#
#                                                  url           ean  \
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540370
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776092321
# 3  https://i5.walmartimages.com/asr/421de5d5-3a74...  701197194311
# 4  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776110773
#
#             upc
# 0  033977045743
# 1  033977045743
# 2  033977045743
# 3  033977045743
# 4  033977045743

# %%
df['id']=[i for i in range(len(df))]

df=df.drop(columns=['upc'])

df.head()
# Out:
#       brand color size  price  \
# 0  MUK LUKS  Grey   10   47.0
# 1  MUK LUKS  Grey    7   47.0
# 2  MUK LUKS  Grey    6   47.0
# 3  MUK LUKS  Grey    9   47.0
# 4  MUK LUKS  Grey    8   47.0
#
#                                                  url           ean  id
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363   0
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540370   1
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776092321   2
# 3  https://i5.walmartimages.com/asr/421de5d5-3a74...  701197194311   3
# 4  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776110773   4

# %% [markdown]
# ### MySQL Connector

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as conn

# %%
# crea una base de datos

crea_db=conn.connect(host='localhost',
                     user='root',
                     passwd='password')

cursor=crea_db.cursor()

cursor.execute('drop database if exists productos')
cursor.execute('create database productos')

# %%
# check

cursor.execute('show databases')

for x in cursor:
    print(x)
# Out:
# ('bank',)
# ('information_schema',)
# ('mydb',)
# ('mysql',)
# ('performance_schema',)
# ('productos',)
# ('prueba_etl',)
# ('publications',)
# ('sakila',)
# ('sys',)
# ('telcom',)
# ('vehicles',)

# %%
# conectar otra vez

db=conn.connect(host='localhost',
                     user='root',
                     passwd='password',
                     database='productos')

cursor=db.cursor()

# %%
# crea una tabla

cursor.execute('drop table if exists zapatos')


tabla='''
            create table zapatos(
                id int,
                brand varchar(50),
                color varchar(50),
                size varchar(50),
                price float,
                url varchar(10000),
                ean varchar(50)
            );
'''


cursor.execute(tabla)

# %%
# check

cursor.execute('show tables')

for x in cursor:
    print(x)
# Out:
# ('zapatos',)

# %% [markdown]
# ### Inserta datos

# %%
# %%time

# insert query  (7.02 sec)

for i in range(len(df)):
    
    insert_query='insert into {} ({}) values {};'\
                 .format('zapatos', 
                         ','.join(df.columns), 
                         tuple(df.iloc[i].values))
    
    cursor.execute(insert_query)
    
db.commit()
# Out:
# CPU times: user 4.56 s, sys: 238 ms, total: 4.8 s
# Wall time: 7 s

# %%
'insert into {} ({}) values {};'\
                 .format('zapatos', 
                         ','.join(df.columns), 
                         tuple(df.iloc[0].values))
# Out:
# "insert into zapatos (brand,color,size,price,url,ean,id) values ('MUK LUKS', 'Grey', '10', 47.0, 'https://i5.walmartimages.com/asr/421de5d5-3a74-4ca2-ae91-a75787f7da41_1.375e3cf74dc82303ce37bdf6a9742610.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/202d5a0e-b2aa-4d47-b63c-661fc3f9cd69_1.a61c1848859953067192fb2ce1c4f916.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/55a10ffd-de74-406b-8aa5-ae5be3569ee3_1.4b179b9702f0076cdf701afd0e7dcda2.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/138e9ecf-fac8-4e9d-946a-7ca33dfa46aa_1.e4211c14f2a6ecf891e3d440402b5f82.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/8c6c1ee4-7708-4d45-b48a-b30f974a5f2f_1.857088c50496451990583941d955218d.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/a486d1cf-f2b5-49ca-b0f8-3e2db896c51c_1.de1c99ac6fdfcf3dc3ddbd9c1c6c72b1.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF'
# ...

# %%
list(df.itertuples())[0]
# Out:
# Pandas(Index=0, brand='MUK LUKS', color='Grey', size='10', price=47.0, url='https://i5.walmartimages.com/asr/421de5d5-3a74-4ca2-ae91-a75787f7da41_1.375e3cf74dc82303ce37bdf6a9742610.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/202d5a0e-b2aa-4d47-b63c-661fc3f9cd69_1.a61c1848859953067192fb2ce1c4f916.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/55a10ffd-de74-406b-8aa5-ae5be3569ee3_1.4b179b9702f0076cdf701afd0e7dcda2.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/138e9ecf-fac8-4e9d-946a-7ca33dfa46aa_1.e4211c14f2a6ecf891e3d440402b5f82.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/8c6c1ee4-7708-4d45-b48a-b30f974a5f2f_1.857088c50496451990583941d955218d.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/a486d1cf-f2b5-49ca-b0f8-3e2db896c51c_1.de1c99ac6fdfcf3dc3ddbd9c1c6c72b1.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF', ean='725177540363', 
# ...

# %% [raw]
# %%time
#
# # insert query
#
# toda_la_query=''
#
# for i in range(len(df)):
#
#     toda_la_query+='insert into {} ({}) values {};'\
#                  .format('zapatos',
#                          ','.join(df.columns),
#                          tuple(df.iloc[i].values))
#
#
# cursor.execute(toda_la_query, multi=True)
#
# db.commit()

# %%
# check

cursor.execute('select * from zapatos limit 1')

for x in cursor:
    print(x)
# Out:
# (0, 'MUK LUKS', 'Grey', '10', 47.0, 'https://i5.walmartimages.com/asr/421de5d5-3a74-4ca2-ae91-a75787f7da41_1.375e3cf74dc82303ce37bdf6a9742610.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/202d5a0e-b2aa-4d47-b63c-661fc3f9cd69_1.a61c1848859953067192fb2ce1c4f916.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/55a10ffd-de74-406b-8aa5-ae5be3569ee3_1.4b179b9702f0076cdf701afd0e7dcda2.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/138e9ecf-fac8-4e9d-946a-7ca33dfa46aa_1.e4211c14f2a6ecf891e3d440402b5f82.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/8c6c1ee4-7708-4d45-b48a-b30f974a5f2f_1.857088c50496451990583941d955218d.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/a486d1cf-f2b5-49ca-b0f8-3e2db896c51c_1.de1c99ac6fdfcf3dc3ddbd9c1c6c72b1.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF', '725177540363')

# %%
df.iloc[1].url
# Out:
# 'https://i5.walmartimages.com/asr/421de5d5-3a74-4ca2-ae91-a75787f7da41_1.375e3cf74dc82303ce37bdf6a9742610.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/202d5a0e-b2aa-4d47-b63c-661fc3f9cd69_1.a61c1848859953067192fb2ce1c4f916.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/55a10ffd-de74-406b-8aa5-ae5be3569ee3_1.4b179b9702f0076cdf701afd0e7dcda2.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/138e9ecf-fac8-4e9d-946a-7ca33dfa46aa_1.e4211c14f2a6ecf891e3d440402b5f82.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/8c6c1ee4-7708-4d45-b48a-b30f974a5f2f_1.857088c50496451990583941d955218d.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/a486d1cf-f2b5-49ca-b0f8-3e2db896c51c_1.de1c99ac6fdfcf3dc3ddbd9c1c6c72b1.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF'

# %% [raw]
# # comentario Ricardo
#
# def cambiar(x):
#     return str(x).lstrip('[').rstrip(']')
#     return str(x)[1:-2]

# %%
# df.columna=df.columna.appy(cambiar)

# %%
df.size=df.size.astype(float)

df.head()
# Out:
#       brand color      size  price  \
# 0  MUK LUKS  Grey  288316.0   47.0
# 1  MUK LUKS  Grey  288316.0   47.0
# 2  MUK LUKS  Grey  288316.0   47.0
# 3  MUK LUKS  Grey  288316.0   47.0
# 4  MUK LUKS  Grey  288316.0   47.0
#
#                                                  url           ean  id
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363   0
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540370   1
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776092321   2
# 3  https://i5.walmartimages.com/asr/421de5d5-3a74...  701197194311   3
# 4  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776110773   4

# %% [markdown]
# ### SqlAlchemy

# %%
# !pip install SQLAlchemy

# %%
# !pip install pymysql

# %%
from sqlalchemy import create_engine

# %%
# string de conexion = lenguaje+driver://usuario:password@servidor:puerto/database

str_conn='mysql+pymysql://root:password@localhost:3306'

motor=create_engine(str_conn)  # motor de conexion

# %%
motor.execute('create database apps;')

# %%
# string de conexion = lenguaje+driver://usuario:password@servidor:puerto/database

str_conn='mysql+pymysql://root:password@localhost:3306/Apps'

motor=create_engine(str_conn)  # motor de conexion

# %%
data=pd.read_csv('data/apple_store.csv')

data.head()
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#    price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 0   3.99             21292                26          4.0              4.5
# 1   0.00            161065                26          4.0              3.5
# 2   0.00            188583              2822          3.5              4.5
# 3   0.00            262241               649          4.0              4.5
# 4   0.00            985920              5320          4.5              5.0
#
#     prime_genre
# 0         Games
# 1  Productivity
# ...

# %%
data.to_sql(name='Ratings', con=motor, if_exists='append', index=False)

# %%
pd.read_sql('select * from Ratings', motor).head()
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#    price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 0   3.99             21292                26          4.0              4.5
# 1   0.00            161065                26          4.0              3.5
# 2   0.00            188583              2822          3.5              4.5
# 3   0.00            262241               649          4.0              4.5
# 4   0.00            985920              5320          4.5              5.0
#
#     prime_genre
# 0         Games
# 1  Productivity
# ...

# %%
len(set(data.id))==len(data)
# Out:
# True

# %% [markdown]
# ### SQL - Pandas

# %%
df_sql=pd.read_sql('select * from zapatos', 
                   con=create_engine('mysql+pymysql://root:password@localhost:3306/productos'))


df_sql.head()
# Out:
#    id     brand color size  price  \
# 0   0  MUK LUKS  Grey   10   47.0
# 1   1  MUK LUKS  Grey    7   47.0
# 2   2  MUK LUKS  Grey    6   47.0
# 3   3  MUK LUKS  Grey    9   47.0
# 4   4  MUK LUKS  Grey    8   47.0
#
#                                                  url           ean
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540370
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776092321
# 3  https://i5.walmartimages.com/asr/421de5d5-3a74...  701197194311
# 4  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776110773

# %%
cursor.execute('select * from zapatos;')

data=cursor.fetchall()

# %%
df=pd.DataFrame(data, columns=cursor.column_names)

df.head()
# Out:
#    id     brand color size  price  \
# 0   0  MUK LUKS  Grey   10   47.0
# 1   1  MUK LUKS  Grey    7   47.0
# 2   2  MUK LUKS  Grey    6   47.0
# 3   3  MUK LUKS  Grey    9   47.0
# 4   4  MUK LUKS  Grey    8   47.0
#
#                                                  url           ean
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540370
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776092321
# 3  https://i5.walmartimages.com/asr/421de5d5-3a74...  701197194311
# 4  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776110773

# %%
data=pd.read_sql('''
                    select track_name, price
                    from Ratings
                    where price=0 and user_rating>4;
                    ''',
                motor)

data.head()
# Out:
#                             track_name  price
# 0                                Bible    0.0
# 1                     Sonos Controller    0.0
# 2  OpenTable - Restaurant Reservations    0.0
# 3                        Chase Mobile℠    0.0
# 4               The Masters Tournament    0.0

# %%
datos=pd.read_sql('''select prime_genre,
                            sum(rating_count_tot) as total_rating,
                            avg(user_rating) as avg_rating
                     from Ratings
                     where price=0
                     group by prime_genre
                     order by total_rating desc
                     limit 10;''', motor)
datos.head()
# Out:
#          prime_genre  total_rating  avg_rating
# 0              Games    42713023.0    3.528578
# 1  Social Networking     7590182.0    2.996503
# 2      Photo & Video     4550732.0    3.793413
# 3              Music     3784296.0    3.940299
# 4      Entertainment     3614869.0    3.148204

# %%
str_conn='mysql+pymysql://root:password@localhost:3306/publications'

motor=create_engine(str_conn)

# %%
query='''
        select group_concat(t.title) as titles,
        t.year
        from (select title, year(max(pubdate)) as 'year',
        count(titleauthor.title_id) as num_titles,
        group_concat(concat(authors.au_fname, ' ', authors.au_lname)) as authors
        from titles
        left join titleauthor
        on titles.title_id=titleauthor.title_id
        left join authors
        on authors.au_id=titleauthor.au_id
        group by titles.title
        order by num_titles desc) as t
        group by t.year;

'''

# %%
df=pd.read_sql(query, motor)

df.head()
# Out:
#                                               titles  year
# 0  Sushi, Anyone?,Computer Phobic AND Non-Phobic ...  1991
# 1                          Secrets of Silicon Valley  1994
# 2   Net Etiquette,The Psychology of Computer Cooking  2014

# %%
# %%time

pd.read_sql('select * from publications.employee', motor)['job_id'].sum()
# Out:
# CPU times: user 8.47 ms, sys: 1.86 ms, total: 10.3 ms
# Wall time: 10.5 ms
# 365

# %%
# %%time

pd.read_sql('select sum(job_id) as colum from publications.employee', motor)['colum'][0]
# Out:
# CPU times: user 4.5 ms, sys: 1.64 ms, total: 6.14 ms
# Wall time: 6.17 ms
# 365.0

# %%
pd.read_sql('show tables;', motor)
# Out:
#    Tables_in_publications
# 0                 authors
# 1               discounts
# 2                employee
# 3                    jobs
# 4                pub_info
# 5              publishers
# 6                roysched
# 7                   sales
# 8                  stores
# 9             titleauthor
# 10                 titles
