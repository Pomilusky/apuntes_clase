# %% [markdown]
# # 3.1 - MongoDB
#
# https://docs.mongodb.com/manual/administration/install-community/
#
# https://docs.mongodb.com/compass/current/install/
#
# MongoDB es una base de datos orientada a documentos. Esto quiere decir que en lugar de guardar los datos en registros, guarda los datos en documentos. Estos documentos son almacenados en BSON, que es una representación binaria de JSON.
#
# Una de las diferencias más importantes con respecto a las bases de datos relacionales, es que no es necesario seguir un esquema. Los documentos de una misma colección, concepto similar a una tabla de una base de datos relacional, pueden tener esquemas diferentes.

# %%
# %pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /Users/iudh/opt/anaconda3/envs/clase/lib/python3.8/site-packages (4.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo  # importa toda la libreria

# %%
cliente=pymongo.MongoClient()  # llamar a la clase MongoClient

db=cliente.nueva_db            # crear una base de datos

# %%
cliente.list_database_names()
# Out:
# ['admin',
#  'arbbot',
#  'companies',
#  'complete_exchange_matches',
#  'config',
#  'local',
#  'telegram_messages']

# %%
colec=db.n_coleccion   # crea coleccion

# %%
db.list_collection_names()
# Out:
# []

# %%
dictio={'nombre':' Juan', 'edad':25}

colec.insert_one(dictio)  # inserta elemento

# %%
cliente.list_database_names()
# Out:
# ['admin',
#  'arbbot',
#  'companies',
#  'complete_exchange_matches',
#  'config',
#  'local',
#  'nueva_db',
#  'telegram_messages']

# %%
db.list_collection_names()
# Out:
# ['n_coleccion']

# %%
colec.insert_many([
    {'nombre':'Ana', 'edad':45},
    {'saludo':'hola pero que pashhhaa', 'altura':50, 'tiempo':50}
])

# inserta varios

# %%
colec.insert_one({'id':0, 'nombre':'Maria', 'edad':45})

# %%
colec.insert_one({'_id':0, 'nombre':'Pepe', 'edad':45}) # cambia id

# %%
list(colec.find())   # encuentra todo
# Out:
# [{'_id': ObjectId('61fbc8b47a28a88c39c8b21e'), 'nombre': ' Juan', 'edad': 25},
#  {'_id': ObjectId('61fbc8b57a28a88c39c8b21f'), 'nombre': 'Ana', 'edad': 45},
#  {'_id': ObjectId('61fbc8b57a28a88c39c8b220'),
#   'saludo': 'hola pero que pashhhaa',
#   'altura': 50,
#   'tiempo': 50},
#  {'_id': ObjectId('61fbc8b57a28a88c39c8b221'),
#   'id': 0,
#   'nombre': 'Maria',
#   'edad': 45},
#  {'_id': 0, 'nombre': 'Pepe', 'edad': 45}]

# %%
list(colec.find().limit(2)) # todo con 2 de limite
# Out:
# [{'_id': ObjectId('61fbc8b47a28a88c39c8b21e'), 'nombre': ' Juan', 'edad': 25},
#  {'_id': ObjectId('61fbc8b57a28a88c39c8b21f'), 'nombre': 'Ana', 'edad': 45}]

# %%
list(colec.find({'edad':25}))  # elemento con edad=25
# Out:
# [{'_id': ObjectId('61fbc8b47a28a88c39c8b21e'), 'nombre': ' Juan', 'edad': 25}]

# %%
list(colec.find({'edad': {'$gte': 25}}))  # elemento con edad>=25
# Out:
# [{'_id': ObjectId('61fbc8b47a28a88c39c8b21e'), 'nombre': ' Juan', 'edad': 25},
#  {'_id': ObjectId('61fbc8b57a28a88c39c8b21f'), 'nombre': 'Ana', 'edad': 45},
#  {'_id': ObjectId('61fbc8b57a28a88c39c8b221'),
#   'id': 0,
#   'nombre': 'Maria',
#   'edad': 45},
#  {'_id': 0, 'nombre': 'Pepe', 'edad': 45}]

# %%
list(colec.find({'edad': {'$gt': 25}}))  # elemento con edad>25
# Out:
# [{'_id': ObjectId('61fbc8b57a28a88c39c8b21f'), 'nombre': 'Ana', 'edad': 45},
#  {'_id': ObjectId('61fbc8b57a28a88c39c8b221'),
#   'id': 0,
#   'nombre': 'Maria',
#   'edad': 45},
#  {'_id': 0, 'nombre': 'Pepe', 'edad': 45}]

# %%
list(colec.find().sort('edad', -1))   # ordenado por las edad descendente -1
# Out:
# [{'_id': ObjectId('61fbc8b57a28a88c39c8b21f'), 'nombre': 'Ana', 'edad': 45},
#  {'_id': ObjectId('61fbc8b57a28a88c39c8b221'),
#   'id': 0,
#   'nombre': 'Maria',
#   'edad': 45},
#  {'_id': 0, 'nombre': 'Pepe', 'edad': 45},
#  {'_id': ObjectId('61fbc8b47a28a88c39c8b21e'), 'nombre': ' Juan', 'edad': 25},
#  {'_id': ObjectId('61fbc8b57a28a88c39c8b220'),
#   'saludo': 'hola pero que pashhhaa',
#   'altura': 50,
#   'tiempo': 50}]

# %%
colec.delete_one({'_id':0})  # borrar un elemento

# %%
list(colec.find())
# Out:
# [{'_id': ObjectId('61fbc8b47a28a88c39c8b21e'), 'nombre': ' Juan', 'edad': 25},
#  {'_id': ObjectId('61fbc8b57a28a88c39c8b21f'), 'nombre': 'Ana', 'edad': 45},
#  {'_id': ObjectId('61fbc8b57a28a88c39c8b220'),
#   'saludo': 'hola pero que pashhhaa',
#   'altura': 50,
#   'tiempo': 50},
#  {'_id': ObjectId('61fbc8b57a28a88c39c8b221'),
#   'id': 0,
#   'nombre': 'Maria',
#   'edad': 45}]

# %%
colec.update_one({'nombre':'Maria', 'id':0}, {'$set': {'nombre': 'Maria Alejandra'}})  # actualizar uno

# %%
list(colec.find())
# Out:
# [{'_id': ObjectId('61fbc8b47a28a88c39c8b21e'), 'nombre': ' Juan', 'edad': 25},
#  {'_id': ObjectId('61fbc8b57a28a88c39c8b21f'), 'nombre': 'Ana', 'edad': 45},
#  {'_id': ObjectId('61fbc8b57a28a88c39c8b220'),
#   'saludo': 'hola pero que pashhhaa',
#   'altura': 50,
#   'tiempo': 50},
#  {'_id': ObjectId('61fbc8b57a28a88c39c8b221'),
#   'id': 0,
#   'nombre': 'Maria Alejandra',
#   'edad': 45}]

# %%
colec.drop()   # elimina coleccion

# %%
db.list_collection_names()
# Out:
# []

# %% [markdown]
# ### Geoqueries

# %%
cliente=pymongo.MongoClient('mongodb://localhost:27017')  # cliente , la conexion por defecto

# %%
db=cliente.companies   # llamada a la base de datos

# %%
al_menos_1_ofi=db.companies.find({'offices': {'$not': {'$size':0}}},
                                 {'name':1, '_id':0, 'offices':1})


# devuelve aquellos elemento con oficinas distintas de cero
# solo el nombre y oficinas

# %%
import pandas as pd

df=pd.DataFrame(al_menos_1_ofi)
df.head()
# Out:
#         name                                            offices
# 0   Wetpaint  [{'description': '', 'address1': '710 - 2nd Av...
# 1  AdventNet  [{'description': 'Headquarters', 'address1': '...
# 2       Zoho  [{'description': 'Headquarters', 'address1': '...
# 3       Digg  [{'description': None, 'address1': '135 Missis...
# 4   Facebook  [{'description': 'Headquarters', 'address1': '...

# %%
df=df.dropna()

# %%
for i in range(len(df.offices[0])):
    print (pd.DataFrame(df.offices[0][i].items()))
# Out:
#               0                 1
# 0   description
# 1      address1  710 - 2nd Avenue
# 2      address2        Suite 1100
# 3      zip_code             98104
# 4          city           Seattle
# 5    state_code                WA
# 6  country_code               USA
# 7      latitude         47.603122
# 8     longitude       -122.333253
#               0                     1
# 0   description
# 1      address1  270 Lafayette Street
# 2      address2             Suite 505
# 3      zip_code                 10012
# 4          city              New York
# 5    state_code                    NY
# 6  country_code                   USA
# 7      latitude             40.723731
# 8     longitude            -73.996431

# %%
jsnn=df.offices.apply(lambda x: pd.json_normalize(x))

jsnn
# Out:
# 0          description              address1    address...
# 1            description          address1   address2 z...
# 2            description         address1   address2 zi...
# 3          description            address1 address2 zip...
# 4            description          address1 address2 zip...
#                                ...
# 13739      description       address1 address2 zip_code...
# 13740         description               address1     ad...
# 13741      description       address1 address2 zip_code...
# 13742      description address1 address2 zip_code      ...
# 13743      description                       address1  ...
# Name: offices, Length: 13744, dtype: object

# %%
display(jsnn[0])
# Out:
#   description              address1    address2 zip_code      city state_code  \
# 0                  710 - 2nd Avenue  Suite 1100    98104   Seattle         WA
# 1              270 Lafayette Street   Suite 505    10012  New York         NY
#
#   country_code   latitude   longitude
# 0          USA  47.603122 -122.333253
# 1          USA  40.723731  -73.996431

# %%
df_n=pd.DataFrame()
for i in range(1000):
    df_n=df_n.append(pd.json_normalize(df.offices[i]), ignore_index=True)

df_n
# Out:
#               description              address1    address2 zip_code  \
# 0                              710 - 2nd Avenue  Suite 1100    98104
# 1                          270 Lafayette Street   Suite 505    10012
# 2            Headquarters      4900 Hopyard Rd.   Suite 310    94588
# 3            Headquarters       4900 Hopyard Rd   Suite 310    94588
# 4                    None    135 Mississippi St                94107
# ...                   ...                   ...         ...      ...
# 1267         Headquarters      112 Broadway St.     Suite B    27701
# 1268      Mailing Address         P.O. Box 1411                27702
# 1269  Shoeboxed Australia        101/65 Hume St                 2065
# 1270                 None      2180a Dwight Way        None    94704
# 1271                 None                              None    10001
#
#                city state_code country_code   latitude   longitude
# 0           Seattle         WA          USA  47.603122 -122.333253
# 1          New York         NY          USA  40.723731  -73.996431
# 2        Pleasanton         CA          USA  37.692934 -121.904945
# 3        Pleasanton         CA          USA  37.692934 -121.904945
# 4     San Francisco         CA          USA  37.764726 -122.394523
# ...             ...        ...          ...        ...         ...
# 1267         Durham         NC          USA  35.996157  -78.902115
# 1268         Durham         NC          USA  35.993900  -78.898600
# 1269     Crows Nest       None          AUS        NaN         NaN
# 1270       Berkeley         CA          USA  37.864221 -122.265466
# 1271                        NY          USA  40.750800  -73.996122
#
# [1272 rows x 9 columns]

# %%
# extrae la primera oficina

def get_first(data):
    data=data['offices']
    
    principal=None
    
    
    if data[0]['latitude'] and data[0]['longitude']:
        # esto ya es una geoquery (geopoint)
        principal={
            'type':'Point',
            'coordinates':[data[0]['longitude'],
                           data[0]['latitude']]
        }
        
    return {'totalOffices': len(data), 
            'lat': data[0]['latitude'],
            'lng': data[0]['longitude'],
            'principal': principal}

# %%
first_office=df[['offices']].apply(get_first, result_type='expand', axis=1)

# %%
first_office.head()
# Out:
#    totalOffices        lat         lng  \
# 0           2.0  47.603122 -122.333253
# 1           1.0  37.692934 -121.904945
# 2           1.0  37.692934 -121.904945
# 3           1.0  37.764726 -122.394523
# 4           3.0  37.416050 -122.151801
#
#                                            principal
# 0  {'type': 'Point', 'coordinates': [-122.333253,...
# 1  {'type': 'Point', 'coordinates': [-121.904945,...
# 2  {'type': 'Point', 'coordinates': [-121.904945,...
# 3  {'type': 'Point', 'coordinates': [-122.394523,...
# 4  {'type': 'Point', 'coordinates': [-122.151801,...

# %%
first_office=first_office.dropna()


df=pd.concat([df, first_office], axis=1).drop(columns=['offices']) # solo para el nombre

df.head()
# Out:
#         name  totalOffices        lat         lng  \
# 0   Wetpaint           2.0  47.603122 -122.333253
# 1  AdventNet           1.0  37.692934 -121.904945
# 2       Zoho           1.0  37.692934 -121.904945
# 3       Digg           1.0  37.764726 -122.394523
# 4   Facebook           3.0  37.416050 -122.151801
#
#                                            principal
# 0  {'type': 'Point', 'coordinates': [-122.333253,...
# 1  {'type': 'Point', 'coordinates': [-121.904945,...
# 2  {'type': 'Point', 'coordinates': [-121.904945,...
# 3  {'type': 'Point', 'coordinates': [-122.394523,...
# 4  {'type': 'Point', 'coordinates': [-122.151801,...

# %%
df=df.dropna()

# %%
df.to_json('data/oficinas.json')    # guarda a json

# %%
db.first_office.insert_many(df.to_dict('records'))  # inserta en mongo

# %%
# crear index 2d

db.first_office.create_index([('principal', '2dsphere')])
# Out:
# 'principal_2dsphere'

# %%
# encuentra los elementos dentro de cierto radio, hace geoquery

def find_near(geopoint, radio=1000):
    
    return db.first_office.find({'principal':{
        '$near': {'$geometry': geopoint, '$maxDistance':radio}
    }})

# %%
# ejemplo

park_avenue={'type': 'Point', 'coordinates':[-73.987308, 40.738935]}  # geopoint

radio=10000  # radio de busqueda

n_ofi=find_near(park_avenue, radio)

list(n_ofi)
# Out:
# [{'_id': ObjectId('61fbc8bd7a28a88c39c8cfd9'),
#   'name': 'SpaBooker',
#   'totalOffices': 1.0,
#   'lat': 40.738567,
#   'lng': -73.987199,
#   'principal': {'type': 'Point', 'coordinates': [-73.987199, 40.738567]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bdb1'),
#   'name': 'HealthiNation',
#   'totalOffices': 1.0,
#   'lat': 40.739341,
#   'lng': -73.988357,
#   'principal': {'type': 'Point', 'coordinates': [-73.988357, 40.739341]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b999'),
#   'name': 'Special Ops Media',
#   'totalOffices': 1.0,
#   'lat': 40.737721,
#   'lng': -73.987725,
#   'principal': {'type': 'Point', 'coordinates': [-73.987725, 40.737721]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d62b'),
#   'name': 'Mashable',
#   'totalOffices': 1.0,
#   'lat': 40.7401544,
#   'lng': -73.9867417,
#   'principal': {'type': 'Point', 'coordinates': [-73.9867417, 40.7401544]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c730'),
#   'name': 'Return Path',
#   'totalOffices': 1.0,
#   'lat': 40.740207,
#   'lng': -73.987002,
#   'principal': {'type': 'Point', 'coordinates': [-73.987002, 40.740207]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b785'),
#   'name': 'Phreesia',
#   'totalOffices': 1.0,
#   'lat': 40.739794,
#   'lng': -73.985878,
#   'principal': {'type': 'Point', 'coordinates': [-73.985878, 40.739794]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8ce75'),
#   'name': 'manageME7',
#   'totalOffices': 1.0,
#   'lat': 40.7376483,
#   'lng': -73.988315,
#   'principal': {'type': 'Point', 'coordinates': [-73.988315, 40.7376483]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c1ff'),
#   'name': 'Gust',
#   'totalOffices': 2.0,
#   'lat': 40.740512,
#   'lng': -73.987794,
#   'principal': {'type': 'Point', 'coordinates': [-73.987794, 40.740512]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c39f'),
#   'name': 'Gust',
#   'totalOffices': 2.0,
#   'lat': 40.740512,
#   'lng': -73.987794,
#   'principal': {'type': 'Point', 'coordinates': [-73.987794, 40.740512]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c537'),
#   'name': 'Voice123',
#   'totalOffices': 1.0,
#   'lat': 40.740512,
#   'lng': -73.987794,
#   'principal': {'type': 'Point', 'coordinates': [-73.987794, 40.740512]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cce3'),
#   'name': 'Comixology',
#   'totalOffices': 1.0,
#   'lat': 40.740512,
#   'lng': -73.987794,
#   'principal': {'type': 'Point', 'coordinates': [-73.987794, 40.740512]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cf33'),
#   'name': 'PerformLine',
#   'totalOffices': 3.0,
#   'lat': 40.740512,
#   'lng': -73.987794,
#   'principal': {'type': 'Point', 'coordinates': [-73.987794, 40.740512]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b922'),
#   'name': 'FeedBackFX',
#   'totalOffices': 1.0,
#   'lat': 40.740348,
#   'lng': -73.985777,
#   'principal': {'type': 'Point', 'coordinates': [-73.985777, 40.740348]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d0ea'),
#   'name': 'HD Cloud',
#   'totalOffices': 1.0,
#   'lat': 40.7391853,
#   'lng': -73.9897456,
#   'principal': {'type': 'Point', 'coordinates': [-73.9897456, 40.7391853]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b57d'),
#   'name': 'BustedTees',
#   'totalOffices': 1.0,
#   'lat': 40.737136,
#   'lng': -73.987973,
#   'principal': {'type': 'Point', 'coordinates': [-73.987973, 40.737136]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b572'),
#   'name': 'BeliefNet',
#   'totalOffices': 1.0,
#   'lat': 40.740231,
#   'lng': -73.985433,
#   'principal': {'type': 'Point', 'coordinates': [-73.985433, 40.740231]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c683'),
#   'name': 'RGA Advisors, LLC',
#   'totalOffices': 2.0,
#   'lat': 40.740145,
#   'lng': -73.985207,
#   'principal': {'type': 'Point', 'coordinates': [-73.985207, 40.740145]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c17b'),
#   'name': 'YellowSpaces',
#   'totalOffices': 1.0,
#   'lat': 40.739867,
#   'lng': -73.990024,
#   'principal': {'type': 'Point', 'coordinates': [-73.990024, 40.739867]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c9a8'),
#   'name': 'Modelinia',
#   'totalOffices': 1.0,
#   'lat': 40.739867,
#   'lng': -73.990024,
#   'principal': {'type': 'Point', 'coordinates': [-73.990024, 40.739867]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c31b'),
#   'name': 'YellowSpaces',
#   'totalOffices': 1.0,
#   'lat': 40.739867,
#   'lng': -73.990024,
#   'principal': {'type': 'Point', 'coordinates': [-73.990024, 40.739867]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bef0'),
#   'name': 'CashEdge',
#   'totalOffices': 3.0,
#   'lat': 40.736796,
#   'lng': -73.988339,
#   'principal': {'type': 'Point', 'coordinates': [-73.988339, 40.736796]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b33b'),
#   'name': 'SelectMinds',
#   'totalOffices': 1.0,
#   'lat': 40.740251,
#   'lng': -73.990004,
#   'principal': {'type': 'Point', 'coordinates': [-73.990004, 40.740251]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b8ff'),
#   'name': 'Business Insider',
#   'totalOffices': 1.0,
#   'lat': 40.73906,
#   'lng': -73.990911,
#   'principal': {'type': 'Point', 'coordinates': [-73.990911, 40.73906]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d23d'),
#   'name': 'Breakaway Communications',
#   'totalOffices': 3.0,
#   'lat': 40.73998,
#   'lng': -73.9907472,
#   'principal': {'type': 'Point', 'coordinates': [-73.9907472, 40.73998]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bd01'),
#   'name': 'MissGift',
#   'totalOffices': 1.0,
#   'lat': 40.737363,
#   'lng': -73.983665,
#   'principal': {'type': 'Point', 'coordinates': [-73.983665, 40.737363]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8ca91'),
#   'name': 'Robotgalaxy',
#   'totalOffices': 1.0,
#   'lat': 40.737216,
#   'lng': -73.990947,
#   'principal': {'type': 'Point', 'coordinates': [-73.990947, 40.737216]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b4b8'),
#   'name': 'eXelate',
#   'totalOffices': 6.0,
#   'lat': 40.741266,
#   'lng': -73.990753,
#   'principal': {'type': 'Point', 'coordinates': [-73.990753, 40.741266]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8ca44'),
#   'name': 'Proclivity Systems',
#   'totalOffices': 1.0,
#   'lat': 40.738954,
#   'lng': -73.992,
#   'principal': {'type': 'Point', 'coordinates': [-73.992, 40.738954]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8caf9'),
#   'name': 'NHA Media',
#   'totalOffices': 1.0,
#   'lat': 40.7382749,
#   'lng': -73.9919538,
#   'principal': {'type': 'Point', 'coordinates': [-73.9919538, 40.7382749]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b8f6'),
#   'name': 'Digital Railroad',
#   'totalOffices': 1.0,
#   'lat': 40.735327,
#   'lng': -73.988469,
#   'principal': {'type': 'Point', 'coordinates': [-73.988469, 40.735327]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b428'),
#   'name': 'Clickable',
#   'totalOffices': 2.0,
#   'lat': 40.7413559,
#   'lng': -73.9912208,
#   'principal': {'type': 'Point', 'coordinates': [-73.9912208, 40.7413559]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bc07'),
#   'name': 'HitTail',
#   'totalOffices': 1.0,
#   'lat': 40.741356,
#   'lng': -73.991222,
#   'principal': {'type': 'Point', 'coordinates': [-73.991222, 40.741356]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c201'),
#   'name': 'Panjiva',
#   'totalOffices': 2.0,
#   'lat': 40.741276,
#   'lng': -73.991561,
#   'principal': {'type': 'Point', 'coordinates': [-73.991561, 40.741276]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c3a1'),
#   'name': 'Panjiva',
#   'totalOffices': 2.0,
#   'lat': 40.741276,
#   'lng': -73.991561,
#   'principal': {'type': 'Point', 'coordinates': [-73.991561, 40.741276]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cbf1'),
#   'name': 'LetMeGo',
#   'totalOffices': 2.0,
#   'lat': 40.7421061,
#   'lng': -73.9909181,
#   'principal': {'type': 'Point', 'coordinates': [-73.9909181, 40.7421061]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d27b'),
#   'name': 'FanFeedr',
#   'totalOffices': 1.0,
#   'lat': 40.7395876,
#   'lng': -73.9928423,
#   'principal': {'type': 'Point', 'coordinates': [-73.9928423, 40.7395876]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b75c'),
#   'name': 'PayLoadz',
#   'totalOffices': 1.0,
#   'lat': 40.738832,
#   'lng': -73.981534,
#   'principal': {'type': 'Point', 'coordinates': [-73.981534, 40.738832]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c7d2'),
#   'name': 'NOM',
#   'totalOffices': 2.0,
#   'lat': 40.740672,
#   'lng': -73.992632,
#   'principal': {'type': 'Point', 'coordinates': [-73.992632, 40.740672]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b934'),
#   'name': 'Cellufun',
#   'totalOffices': 1.0,
#   'lat': 40.73993,
#   'lng': -73.9930489,
#   'principal': {'type': 'Point', 'coordinates': [-73.9930489, 40.73993]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c64b'),
#   'name': 'Buzzr',
#   'totalOffices': 1.0,
#   'lat': 40.740941,
#   'lng': -73.992609,
#   'principal': {'type': 'Point', 'coordinates': [-73.992609, 40.740941]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cd26'),
#   'name': 'TRAFFIQ',
#   'totalOffices': 1.0,
#   'lat': 40.7429533,
#   'lng': -73.9844611,
#   'principal': {'type': 'Point', 'coordinates': [-73.9844611, 40.7429533]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b450'),
#   'name': 'Empressr',
#   'totalOffices': 1.0,
#   'lat': 40.740337,
#   'lng': -73.993127,
#   'principal': {'type': 'Point', 'coordinates': [-73.993127, 40.740337]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cbf8'),
#   'name': 'Web Foundation',
#   'totalOffices': 1.0,
#   'lat': 40.7391656,
#   'lng': -73.9934067,
#   'principal': {'type': 'Point', 'coordinates': [-73.9934067, 40.7391656]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d193'),
#   'name': 'Bluewolf',
#   'totalOffices': 5.0,
#   'lat': 40.743616,
#   'lng': -73.9880796,
#   'principal': {'type': 'Point', 'coordinates': [-73.9880796, 40.743616]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cdbe'),
#   'name': 'Milabra',
#   'totalOffices': 1.0,
#   'lat': 40.743616,
#   'lng': -73.9880796,
#   'principal': {'type': 'Point', 'coordinates': [-73.9880796, 40.743616]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bc6a'),
#   'name': 'Dotmenu',
#   'totalOffices': 1.0,
#   'lat': 40.740162,
#   'lng': -73.993367,
#   'principal': {'type': 'Point', 'coordinates': [-73.993367, 40.740162]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c392'),
#   'name': 'ShopWiki',
#   'totalOffices': 1.0,
#   'lat': 40.740441,
#   'lng': -73.993376,
#   'principal': {'type': 'Point', 'coordinates': [-73.993376, 40.740441]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c1f2'),
#   'name': 'ShopWiki',
#   'totalOffices': 1.0,
#   'lat': 40.740441,
#   'lng': -73.993376,
#   'principal': {'type': 'Point', 'coordinates': [-73.993376, 40.740441]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b546'),
#   'name': 'Yodle',
#   'totalOffices': 5.0,
#   'lat': 40.742459,
#   'lng': -73.9918126,
#   'principal': {'type': 'Point', 'coordinates': [-73.9918126, 40.742459]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bdbb'),
#   'name': 'Flow TV',
#   'totalOffices': 1.0,
#   'lat': 40.741557,
#   'lng': -73.981829,
#   'principal': {'type': 'Point', 'coordinates': [-73.981829, 40.741557]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c108'),
#   'name': 'Hunch',
#   'totalOffices': 1.0,
#   'lat': 40.741179,
#   'lng': -73.993182,
#   'principal': {'type': 'Point', 'coordinates': [-73.993182, 40.741179]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c74a'),
#   'name': 'Aditall',
#   'totalOffices': 1.0,
#   'lat': 40.743165,
#   'lng': -73.990853,
#   'principal': {'type': 'Point', 'coordinates': [-73.990853, 40.743165]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d2b1'),
#   'name': '[212]Media',
#   'totalOffices': 1.0,
#   'lat': 40.743877,
#   'lng': -73.98618,
#   'principal': {'type': 'Point', 'coordinates': [-73.98618, 40.743877]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d2b0'),
#   'name': 'Saavn',
#   'totalOffices': 1.0,
#   'lat': 40.743877,
#   'lng': -73.98618,
#   'principal': {'type': 'Point', 'coordinates': [-73.98618, 40.743877]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b916'),
#   'name': 'Dimestore Media',
#   'totalOffices': 1.0,
#   'lat': 40.738395,
#   'lng': -73.993906,
#   'principal': {'type': 'Point', 'coordinates': [-73.993906, 40.738395]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cc2e'),
#   'name': 'Ticketpredator',
#   'totalOffices': 1.0,
#   'lat': 40.7438356,
#   'lng': -73.9890149,
#   'principal': {'type': 'Point', 'coordinates': [-73.9890149, 40.7438356]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d722'),
#   'name': 'FremantleMedia Ventures',
#   'totalOffices': 1.0,
#   'lat': 40.7439449,
#   'lng': -73.9855424,
#   'principal': {'type': 'Point', 'coordinates': [-73.9855424, 40.7439449]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b2fc'),
#   'name': 'Forbes',
#   'totalOffices': 1.0,
#   'lat': 40.736416,
#   'lng': -73.993302,
#   'principal': {'type': 'Point', 'coordinates': [-73.993302, 40.736416]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b6e8'),
#   'name': 'MediaTrust',
#   'totalOffices': 1.0,
#   'lat': 40.743662,
#   'lng': -73.984268,
#   'principal': {'type': 'Point', 'coordinates': [-73.984268, 40.743662]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c1be'),
#   'name': 'myJambi',
#   'totalOffices': 1.0,
#   'lat': 40.74385,
#   'lng': -73.98458,
#   'principal': {'type': 'Point', 'coordinates': [-73.98458, 40.74385]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c35e'),
#   'name': 'myJambi',
#   'totalOffices': 1.0,
#   'lat': 40.74385,
#   'lng': -73.98458,
#   'principal': {'type': 'Point', 'coordinates': [-73.98458, 40.74385]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8ba6e'),
#   'name': 'BeenVerified',
#   'totalOffices': 1.0,
#   'lat': 40.744402,
#   'lng': -73.987949,
#   'principal': {'type': 'Point', 'coordinates': [-73.987949, 40.744402]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c739'),
#   'name': 'ZepFrog Corp',
#   'totalOffices': 1.0,
#   'lat': 40.744201,
#   'lng': -73.989505,
#   'principal': {'type': 'Point', 'coordinates': [-73.989505, 40.744201]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b3c6'),
#   'name': 'BBE',
#   'totalOffices': 1.0,
#   'lat': 40.7445343,
#   'lng': -73.9874008,
#   'principal': {'type': 'Point', 'coordinates': [-73.9874008, 40.7445343]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b80e'),
#   'name': 'Next New Networks',
#   'totalOffices': 1.0,
#   'lat': 40.743808,
#   'lng': -73.983626,
#   'principal': {'type': 'Point', 'coordinates': [-73.983626, 40.743808]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b49c'),
#   'name': 'Davidville',
#   'totalOffices': 1.0,
#   'lat': 40.743808,
#   'lng': -73.983626,
#   'principal': {'type': 'Point', 'coordinates': [-73.983626, 40.743808]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b49b'),
#   'name': 'Tumblr',
#   'totalOffices': 1.0,
#   'lat': 40.743808,
#   'lng': -73.983626,
#   'principal': {'type': 'Point', 'coordinates': [-73.983626, 40.743808]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c735'),
#   'name': 'Yipit',
#   'totalOffices': 1.0,
#   'lat': 40.744618,
#   'lng': -73.987764,
#   'principal': {'type': 'Point', 'coordinates': [-73.987764, 40.744618]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d034'),
#   'name': 'IntheGlo',
#   'totalOffices': 1.0,
#   'lat': 40.744618,
#   'lng': -73.987764,
#   'principal': {'type': 'Point', 'coordinates': [-73.987764, 40.744618]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bdc1'),
#   'name': 'Gameloft',
#   'totalOffices': 1.0,
#   'lat': 40.744034,
#   'lng': -73.991034,
#   'principal': {'type': 'Point', 'coordinates': [-73.991034, 40.744034]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c4c2'),
#   'name': 'Buzzd',
#   'totalOffices': 1.0,
#   'lat': 40.733928,
#   'lng': -73.991334,
#   'principal': {'type': 'Point', 'coordinates': [-73.991334, 40.733928]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c67d'),
#   'name': 'For Your Imagination',
#   'totalOffices': 1.0,
#   'lat': 40.744594,
#   'lng': -73.989698,
#   'principal': {'type': 'Point', 'coordinates': [-73.989698, 40.744594]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cb4c'),
#   'name': 'Infor',
#   'totalOffices': 1.0,
#   'lat': 40.740976,
#   'lng': -73.9947229,
#   'principal': {'type': 'Point', 'coordinates': [-73.9947229, 40.740976]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b9c1'),
#   'name': 'Someecards',
#   'totalOffices': 1.0,
#   'lat': 40.737778,
#   'lng': -73.979508,
#   'principal': {'type': 'Point', 'coordinates': [-73.979508, 40.737778]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d4e2'),
#   'name': 'Zemoga',
#   'totalOffices': 4.0,
#   'lat': 40.744697,
#   'lng': -73.989947,
#   'principal': {'type': 'Point', 'coordinates': [-73.989947, 40.744697]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d085'),
#   'name': 'Chartbeat',
#   'totalOffices': 1.0,
#   'lat': 40.73343,
#   'lng': -73.990967,
#   'principal': {'type': 'Point', 'coordinates': [-73.990967, 40.73343]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d16e'),
#   'name': 'Oyster Digital Media',
#   'totalOffices': 1.0,
#   'lat': 40.738495,
#   'lng': -73.9954473,
#   'principal': {'type': 'Point', 'coordinates': [-73.9954473, 40.738495]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b924'),
#   'name': 'Bonobos',
#   'totalOffices': 1.0,
#   'lat': 40.7384997,
#   'lng': -73.9954585,
#   'principal': {'type': 'Point', 'coordinates': [-73.9954585, 40.7384997]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c736'),
#   'name': 'Next Jump',
#   'totalOffices': 1.0,
#   'lat': 40.7451545,
#   'lng': -73.9869549,
#   'principal': {'type': 'Point', 'coordinates': [-73.9869549, 40.7451545]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b712'),
#   'name': 'Inform Technologies',
#   'totalOffices': 1.0,
#   'lat': 40.744639,
#   'lng': -73.983963,
#   'principal': {'type': 'Point', 'coordinates': [-73.983963, 40.744639]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b700'),
#   'name': '8coupons',
#   'totalOffices': 1.0,
#   'lat': 40.7431477,
#   'lng': -73.9934288,
#   'principal': {'type': 'Point', 'coordinates': [-73.9934288, 40.7431477]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b674'),
#   'name': 'stickK',
#   'totalOffices': 1.0,
#   'lat': 40.744837,
#   'lng': -73.983843,
#   'principal': {'type': 'Point', 'coordinates': [-73.983843, 40.744837]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8be2b'),
#   'name': 'Lolz',
#   'totalOffices': 1.0,
#   'lat': 40.743563,
#   'lng': -73.993274,
#   'principal': {'type': 'Point', 'coordinates': [-73.993274, 40.743563]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bb18'),
#   'name': 'Subway Crush',
#   'totalOffices': 1.0,
#   'lat': 40.743563,
#   'lng': -73.993274,
#   'principal': {'type': 'Point', 'coordinates': [-73.993274, 40.743563]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d67f'),
#   'name': 'StyleCaster',
#   'totalOffices': 1.0,
#   'lat': 40.7450497,
#   'lng': -73.9900984,
#   'principal': {'type': 'Point', 'coordinates': [-73.9900984, 40.7450497]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8ce70'),
#   'name': 'HItviews',
#   'totalOffices': 2.0,
#   'lat': 40.733201,
#   'lng': -73.991535,
#   'principal': {'type': 'Point', 'coordinates': [-73.991535, 40.733201]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bea0'),
#   'name': 'OkCupid',
#   'totalOffices': 1.0,
#   'lat': 40.7368158,
#   'lng': -73.9955426,
#   'principal': {'type': 'Point', 'coordinates': [-73.9955426, 40.7368158]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b8b3'),
#   'name': 'Reprise Media',
#   'totalOffices': 2.0,
#   'lat': 40.734722,
#   'lng': -73.994078,
#   'principal': {'type': 'Point', 'coordinates': [-73.994078, 40.734722]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d212'),
#   'name': 'Navatar Group',
#   'totalOffices': 2.0,
#   'lat': 40.733242,
#   'lng': -73.991877,
#   'principal': {'type': 'Point', 'coordinates': [-73.991877, 40.733242]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bc40'),
#   'name': 'Socialight',
#   'totalOffices': 1.0,
#   'lat': 40.733386,
#   'lng': -73.992189,
#   'principal': {'type': 'Point', 'coordinates': [-73.992189, 40.733386]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d18c'),
#   'name': 'FledgeWing',
#   'totalOffices': 1.0,
#   'lat': 40.7322535,
#   'lng': -73.9874105,
#   'principal': {'type': 'Point', 'coordinates': [-73.9874105, 40.7322535]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bb0e'),
#   'name': 'Tabbery',
#   'totalOffices': 1.0,
#   'lat': 40.732525,
#   'lng': -73.990076,
#   'principal': {'type': 'Point', 'coordinates': [-73.990076, 40.732525]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bf83'),
#   'name': 'Urgent Career',
#   'totalOffices': 1.0,
#   'lat': 40.745003,
#   'lng': -73.983229,
#   'principal': {'type': 'Point', 'coordinates': [-73.983229, 40.745003]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c919'),
#   'name': 'CyberSynchs',
#   'totalOffices': 1.0,
#   'lat': 40.745534,
#   'lng': -73.990033,
#   'principal': {'type': 'Point', 'coordinates': [-73.990033, 40.745534]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b464'),
#   'name': 'Mimeo',
#   'totalOffices': 1.0,
#   'lat': 40.745216,
#   'lng': -73.982807,
#   'principal': {'type': 'Point', 'coordinates': [-73.982807, 40.745216]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b3b2'),
#   'name': 'MIVA',
#   'totalOffices': 1.0,
#   'lat': 40.733276,
#   'lng': -73.9932793,
#   'principal': {'type': 'Point', 'coordinates': [-73.9932793, 40.733276]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bd9d'),
#   'name': 'Ziki',
#   'totalOffices': 1.0,
#   'lat': 40.733276,
#   'lng': -73.9932793,
#   'principal': {'type': 'Point', 'coordinates': [-73.9932793, 40.733276]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d528'),
#   'name': 'YCD Multimedia',
#   'totalOffices': 3.0,
#   'lat': 40.745454,
#   'lng': -73.991674,
#   'principal': {'type': 'Point', 'coordinates': [-73.991674, 40.745454]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b86e'),
#   'name': 'Monitor110',
#   'totalOffices': 1.0,
#   'lat': 40.732748,
#   'lng': -73.992607,
#   'principal': {'type': 'Point', 'coordinates': [-73.992607, 40.732748]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cee2'),
#   'name': 'Imaginova',
#   'totalOffices': 1.0,
#   'lat': 40.7454971,
#   'lng': -73.9826042,
#   'principal': {'type': 'Point', 'coordinates': [-73.9826042, 40.7454971]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bbc4'),
#   'name': '[x+1]',
#   'totalOffices': 1.0,
#   'lat': 40.7455068,
#   'lng': -73.982624,
#   'principal': {'type': 'Point', 'coordinates': [-73.982624, 40.7455068]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cc02'),
#   'name': '[x+1]',
#   'totalOffices': 1.0,
#   'lat': 40.7455068,
#   'lng': -73.982624,
#   'principal': {'type': 'Point', 'coordinates': [-73.982624, 40.7455068]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c025'),
#   'name': 'GEN ART',
#   'totalOffices': 1.0,
#   'lat': 40.744943,
#   'lng': -73.993179,
#   'principal': {'type': 'Point', 'coordinates': [-73.993179, 40.744943]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c34d'),
#   'name': 'GoldMic',
#   'totalOffices': 1.0,
#   'lat': 40.731392,
#   'lng': -73.9884,
#   'principal': {'type': 'Point', 'coordinates': [-73.9884, 40.731392]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c1ad'),
#   'name': 'GoldMic',
#   'totalOffices': 1.0,
#   'lat': 40.731392,
#   'lng': -73.9884,
#   'principal': {'type': 'Point', 'coordinates': [-73.9884, 40.731392]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bc74'),
#   'name': "Guru's Feet",
#   'totalOffices': 1.0,
#   'lat': 40.731392,
#   'lng': -73.9884,
#   'principal': {'type': 'Point', 'coordinates': [-73.9884, 40.731392]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8be2f'),
#   'name': 'ListensToYou',
#   'totalOffices': 1.0,
#   'lat': 40.731392,
#   'lng': -73.9884,
#   'principal': {'type': 'Point', 'coordinates': [-73.9884, 40.731392]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bba8'),
#   'name': 'findingDulcinea',
#   'totalOffices': 1.0,
#   'lat': 40.7455579,
#   'lng': -73.9823449,
#   'principal': {'type': 'Point', 'coordinates': [-73.9823449, 40.7455579]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bf3e'),
#   'name': 'Xandros',
#   'totalOffices': 7.0,
#   'lat': 40.746368,
#   'lng': -73.983972,
#   'principal': {'type': 'Point', 'coordinates': [-73.983972, 40.746368]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c4e7'),
#   'name': 'NFL',
#   'totalOffices': 1.0,
#   'lat': 40.7457865,
#   'lng': -73.9822265,
#   'principal': {'type': 'Point', 'coordinates': [-73.9822265, 40.7457865]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d177'),
#   'name': 'Catchafire',
#   'totalOffices': 1.0,
#   'lat': 40.746417,
#   'lng': -73.983171,
#   'principal': {'type': 'Point', 'coordinates': [-73.983171, 40.746417]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b764'),
#   'name': 'Right Media',
#   'totalOffices': 1.0,
#   'lat': 40.74632,
#   'lng': -73.982607,
#   'principal': {'type': 'Point', 'coordinates': [-73.982607, 40.74632]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c130'),
#   'name': 'Conductor',
#   'totalOffices': 1.0,
#   'lat': 40.746332,
#   'lng': -73.982596,
#   'principal': {'type': 'Point', 'coordinates': [-73.982596, 40.746332]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b7d1'),
#   'name': 'Tripology',
#   'totalOffices': 1.0,
#   'lat': 40.746883,
#   'lng': -73.983969,
#   'principal': {'type': 'Point', 'coordinates': [-73.983969, 40.746883]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b31d'),
#   'name': 'AOL',
#   'totalOffices': 1.0,
#   'lat': 40.7311317,
#   'lng': -73.9919311,
#   'principal': {'type': 'Point', 'coordinates': [-73.9919311, 40.7311317]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bf6b'),
#   'name': 'Nielsen Online',
#   'totalOffices': 1.0,
#   'lat': 40.7311317,
#   'lng': -73.9919311,
#   'principal': {'type': 'Point', 'coordinates': [-73.9919311, 40.7311317]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b390'),
#   'name': 'Nielsen',
#   'totalOffices': 1.0,
#   'lat': 40.731118,
#   'lng': -73.991933,
#   'principal': {'type': 'Point', 'coordinates': [-73.991933, 40.731118]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b391'),
#   'name': 'Buzzmetrics',
#   'totalOffices': 1.0,
#   'lat': 40.731118,
#   'lng': -73.991933,
#   'principal': {'type': 'Point', 'coordinates': [-73.991933, 40.731118]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c035'),
#   'name': 'VISUALPLANT',
#   'totalOffices': 1.0,
#   'lat': 40.738476,
#   'lng': -73.998726,
#   'principal': {'type': 'Point', 'coordinates': [-73.998726, 40.738476]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b87d'),
#   'name': 'Athena Archiver',
#   'totalOffices': 1.0,
#   'lat': 40.747003,
#   'lng': -73.991562,
#   'principal': {'type': 'Point', 'coordinates': [-73.991562, 40.747003]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c0f6'),
#   'name': 'Yellow SEO',
#   'totalOffices': 1.0,
#   'lat': 40.747003,
#   'lng': -73.991562,
#   'principal': {'type': 'Point', 'coordinates': [-73.991562, 40.747003]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d449'),
#   'name': 'Ramp Up Tech',
#   'totalOffices': 1.0,
#   'lat': 40.746514,
#   'lng': -73.993035,
#   'principal': {'type': 'Point', 'coordinates': [-73.993035, 40.746514]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c67e'),
#   'name': 'RateZip',
#   'totalOffices': 1.0,
#   'lat': 40.731085,
#   'lng': -73.992633,
#   'principal': {'type': 'Point', 'coordinates': [-73.992633, 40.731085]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cebf'),
#   'name': 'SwitchGames',
#   'totalOffices': 1.0,
#   'lat': 40.7297485,
#   'lng': -73.9867361,
#   'principal': {'type': 'Point', 'coordinates': [-73.9867361, 40.7297485]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b399'),
#   'name': 'Burnlounge',
#   'totalOffices': 1.0,
#   'lat': 40.746953,
#   'lng': -73.993553,
#   'principal': {'type': 'Point', 'coordinates': [-73.993553, 40.746953]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cfb0'),
#   'name': 'IrishCentral',
#   'totalOffices': 1.0,
#   'lat': 40.74828,
#   'lng': -73.989276,
#   'principal': {'type': 'Point', 'coordinates': [-73.989276, 40.74828]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c6de'),
#   'name': 'TasteSpace',
#   'totalOffices': 1.0,
#   'lat': 40.747819,
#   'lng': -73.982544,
#   'principal': {'type': 'Point', 'coordinates': [-73.982544, 40.747819]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bda9'),
#   'name': 'RRD USA',
#   'totalOffices': 1.0,
#   'lat': 40.748342,
#   'lng': -73.984606,
#   'principal': {'type': 'Point', 'coordinates': [-73.984606, 40.748342]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c49d'),
#   'name': 'Samepoint',
#   'totalOffices': 1.0,
#   'lat': 40.741441,
#   'lng': -73.999675,
#   'principal': {'type': 'Point', 'coordinates': [-73.999675, 40.741441]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c2fd'),
#   'name': 'Samepoint',
#   'totalOffices': 1.0,
#   'lat': 40.741441,
#   'lng': -73.999675,
#   'principal': {'type': 'Point', 'coordinates': [-73.999675, 40.741441]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d432'),
#   'name': 'Synesis IT',
#   'totalOffices': 2.0,
#   'lat': 40.748873,
#   'lng': -73.987106,
#   'principal': {'type': 'Point', 'coordinates': [-73.987106, 40.748873]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8ce83'),
#   'name': 'Portero',
#   'totalOffices': 1.0,
#   'lat': 40.74727,
#   'lng': -73.9800645,
#   'principal': {'type': 'Point', 'coordinates': [-73.9800645, 40.74727]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d41d'),
#   'name': 'Dice Holdings',
#   'totalOffices': 1.0,
#   'lat': 40.74727,
#   'lng': -73.9800645,
#   'principal': {'type': 'Point', 'coordinates': [-73.9800645, 40.74727]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b570'),
#   'name': 'Gilt Groupe',
#   'totalOffices': 1.0,
#   'lat': 40.74727,
#   'lng': -73.9800645,
#   'principal': {'type': 'Point', 'coordinates': [-73.9800645, 40.74727]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c88e'),
#   'name': 'Carbonmade',
#   'totalOffices': 1.0,
#   'lat': 40.74727,
#   'lng': -73.9800645,
#   'principal': {'type': 'Point', 'coordinates': [-73.9800645, 40.74727]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d3cd'),
#   'name': 'Covet Shop',
#   'totalOffices': 1.0,
#   'lat': 40.72874,
#   'lng': -73.989324,
#   'principal': {'type': 'Point', 'coordinates': [-73.989324, 40.72874]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bd2b'),
#   'name': 'FoxyMelody',
#   'totalOffices': 1.0,
#   'lat': 40.74149,
#   'lng': -74.000709,
#   'principal': {'type': 'Point', 'coordinates': [-74.000709, 40.74149]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b604'),
#   'name': 'Qtrax',
#   'totalOffices': 1.0,
#   'lat': 40.748641,
#   'lng': -73.981947,
#   'principal': {'type': 'Point', 'coordinates': [-73.981947, 40.748641]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d360'),
#   'name': 'ArtNeighbor',
#   'totalOffices': 1.0,
#   'lat': 40.7489381,
#   'lng': -73.9918181,
#   'principal': {'type': 'Point', 'coordinates': [-73.9918181, 40.7489381]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d437'),
#   'name': 'Strategist News',
#   'totalOffices': 1.0,
#   'lat': 40.7489381,
#   'lng': -73.9918181,
#   'principal': {'type': 'Point', 'coordinates': [-73.9918181, 40.7489381]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d248'),
#   'name': 'Live2Support',
#   'totalOffices': 1.0,
#   'lat': 40.7488761,
#   'lng': -73.9815793,
#   'principal': {'type': 'Point', 'coordinates': [-73.9815793, 40.7488761]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bd40'),
#   'name': 'TickerHound',
#   'totalOffices': 1.0,
#   'lat': 40.728623,
#   'lng': -73.991924,
#   'principal': {'type': 'Point', 'coordinates': [-73.991924, 40.728623]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b961'),
#   'name': 'WebMD',
#   'totalOffices': 1.0,
#   'lat': 40.7410886,
#   'lng': -74.0015261,
#   'principal': {'type': 'Point', 'coordinates': [-74.0015261, 40.7410886]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b675'),
#   'name': 'DoubleClick',
#   'totalOffices': 1.0,
#   'lat': 40.741089,
#   'lng': -74.001526,
#   'principal': {'type': 'Point', 'coordinates': [-74.001526, 40.741089]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c821'),
#   'name': 'BarterQuest',
#   'totalOffices': 1.0,
#   'lat': 40.748634,
#   'lng': -73.994203,
#   'principal': {'type': 'Point', 'coordinates': [-73.994203, 40.748634]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bfcc'),
#   'name': 'American Higher Education Development',
#   'totalOffices': 1.0,
#   'lat': 40.749559,
#   'lng': -73.991662,
#   'principal': {'type': 'Point', 'coordinates': [-73.991662, 40.749559]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c606'),
#   'name': 'Relegence',
#   'totalOffices': 1.0,
#   'lat': 40.7495594,
#   'lng': -73.9916617,
#   'principal': {'type': 'Point', 'coordinates': [-73.9916617, 40.7495594]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8ce56'),
#   'name': 'CollegeClickTV',
#   'totalOffices': 1.0,
#   'lat': 40.7495594,
#   'lng': -73.9916617,
#   'principal': {'type': 'Point', 'coordinates': [-73.9916617, 40.7495594]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c954'),
#   'name': 'Novalsys',
#   'totalOffices': 1.0,
#   'lat': 40.7283696,
#   'lng': -73.9923918,
#   'principal': {'type': 'Point', 'coordinates': [-73.9923918, 40.7283696]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8ba47'),
#   'name': 'Social Median',
#   'totalOffices': 1.0,
#   'lat': 40.74963,
#   'lng': -73.982575,
#   'principal': {'type': 'Point', 'coordinates': [-73.982575, 40.74963]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d174'),
#   'name': 'TrialX',
#   'totalOffices': 1.0,
#   'lat': 40.7277434,
#   'lng': -73.9893359,
#   'principal': {'type': 'Point', 'coordinates': [-73.9893359, 40.7277434]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cf09'),
#   'name': 'Crispy Gamer',
#   'totalOffices': 1.0,
#   'lat': 40.750597,
#   'lng': -73.985273,
#   'principal': {'type': 'Point', 'coordinates': [-73.985273, 40.750597]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b53d'),
#   'name': 'Fotki',
#   'totalOffices': 1.0,
#   'lat': 40.750823,
#   'lng': -73.985833,
#   'principal': {'type': 'Point', 'coordinates': [-73.985833, 40.750823]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c022'),
#   'name': 'Converseon',
#   'totalOffices': 1.0,
#   'lat': 40.750823,
#   'lng': -73.985833,
#   'principal': {'type': 'Point', 'coordinates': [-73.985833, 40.750823]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d29a'),
#   'name': 'Simparel',
#   'totalOffices': 1.0,
#   'lat': 40.750823,
#   'lng': -73.985833,
#   'principal': {'type': 'Point', 'coordinates': [-73.985833, 40.750823]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d0cd'),
#   'name': 'OneBigPlanet',
#   'totalOffices': 1.0,
#   'lat': 40.7501311,
#   'lng': -73.9812417,
#   'principal': {'type': 'Point', 'coordinates': [-73.9812417, 40.7501311]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bdcd'),
#   'name': 'Marvel Entertainment',
#   'totalOffices': 2.0,
#   'lat': 40.750576,
#   'lng': -73.982713,
#   'principal': {'type': 'Point', 'coordinates': [-73.982713, 40.750576]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bd42'),
#   'name': 'Plentitube',
#   'totalOffices': 1.0,
#   'lat': 40.749277,
#   'lng': -73.978733,
#   'principal': {'type': 'Point', 'coordinates': [-73.978733, 40.749277]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c7ab'),
#   'name': 'WeTxt',
#   'totalOffices': 1.0,
#   'lat': 40.740837,
#   'lng': -74.003466,
#   'principal': {'type': 'Point', 'coordinates': [-74.003466, 40.740837]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d564'),
#   'name': 'Extricom',
#   'totalOffices': 2.0,
#   'lat': 40.72641,
#   'lng': -73.984716,
#   'principal': {'type': 'Point', 'coordinates': [-73.984716, 40.72641]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b282'),
#   'name': 'KickApps',
#   'totalOffices': 4.0,
#   'lat': 40.7516611,
#   'lng': -73.9843328,
#   'principal': {'type': 'Point', 'coordinates': [-73.9843328, 40.7516611]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cbad'),
#   'name': 'UGO Entertainment',
#   'totalOffices': 1.0,
#   'lat': 40.727216,
#   'lng': -73.994797,
#   'principal': {'type': 'Point', 'coordinates': [-73.994797, 40.727216]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cf47'),
#   'name': 'Simulmedia',
#   'totalOffices': 1.0,
#   'lat': 40.727216,
#   'lng': -73.994797,
#   'principal': {'type': 'Point', 'coordinates': [-73.994797, 40.727216]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8ba6c'),
#   'name': 'Scanbuy',
#   'totalOffices': 1.0,
#   'lat': 40.7512062,
#   'lng': -73.9815333,
#   'principal': {'type': 'Point', 'coordinates': [-73.9815333, 40.7512062]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c469'),
#   'name': 'Stylesight',
#   'totalOffices': 1.0,
#   'lat': 40.730763,
#   'lng': -74.000827,
#   'principal': {'type': 'Point', 'coordinates': [-74.000827, 40.730763]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c2c9'),
#   'name': 'Stylesight',
#   'totalOffices': 1.0,
#   'lat': 40.730763,
#   'lng': -74.000827,
#   'principal': {'type': 'Point', 'coordinates': [-74.000827, 40.730763]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d151'),
#   'name': 'Stream57',
#   'totalOffices': 2.0,
#   'lat': 40.751969,
#   'lng': -73.99031,
#   'principal': {'type': 'Point', 'coordinates': [-73.99031, 40.751969]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bee7'),
#   'name': 'LivePerson',
#   'totalOffices': 4.0,
#   'lat': 40.751969,
#   'lng': -73.99031,
#   'principal': {'type': 'Point', 'coordinates': [-73.99031, 40.751969]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c63b'),
#   'name': 'Fabian Rossano Studio',
#   'totalOffices': 1.0,
#   'lat': 40.740371,
#   'lng': -74.004777,
#   'principal': {'type': 'Point', 'coordinates': [-74.004777, 40.740371]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b67f'),
#   'name': 'Oddcast',
#   'totalOffices': 1.0,
#   'lat': 40.752325,
#   'lng': -73.988477,
#   'principal': {'type': 'Point', 'coordinates': [-73.988477, 40.752325]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d72a'),
#   'name': 'Genesiz',
#   'totalOffices': 1.0,
#   'lat': 40.752143,
#   'lng': -73.990675,
#   'principal': {'type': 'Point', 'coordinates': [-73.990675, 40.752143]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b908'),
#   'name': 'Social Sauce',
#   'totalOffices': 1.0,
#   'lat': 40.752143,
#   'lng': -73.990675,
#   'principal': {'type': 'Point', 'coordinates': [-73.990675, 40.752143]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cccd'),
#   'name': 'Transit Treasure',
#   'totalOffices': 1.0,
#   'lat': 40.74724,
#   'lng': -73.973243,
#   'principal': {'type': 'Point', 'coordinates': [-73.973243, 40.74724]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cb80'),
#   'name': 'Eastmedia',
#   'totalOffices': 1.0,
#   'lat': 40.752409,
#   'lng': -73.988676,
#   'principal': {'type': 'Point', 'coordinates': [-73.988676, 40.752409]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c8f5'),
#   'name': 'MLB Advanced Media',
#   'totalOffices': 1.0,
#   'lat': 40.7418877,
#   'lng': -74.0047466,
#   'principal': {'type': 'Point', 'coordinates': [-74.0047466, 40.7418877]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b439'),
#   'name': 'Animoto',
#   'totalOffices': 2.0,
#   'lat': 40.72948,
#   'lng': -74.000195,
#   'principal': {'type': 'Point', 'coordinates': [-74.000195, 40.72948]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cc28'),
#   'name': 'PEX Card',
#   'totalOffices': 1.0,
#   'lat': 40.752539,
#   'lng': -73.987871,
#   'principal': {'type': 'Point', 'coordinates': [-73.987871, 40.752539]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b585'),
#   'name': 'GoLark',
#   'totalOffices': 1.0,
#   'lat': 40.7508,
#   'lng': -73.996122,
#   'principal': {'type': 'Point', 'coordinates': [-73.996122, 40.7508]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d306'),
#   'name': 'YEAONAY',
#   'totalOffices': 1.0,
#   'lat': 40.751234,
#   'lng': -73.9952442,
#   'principal': {'type': 'Point', 'coordinates': [-73.9952442, 40.751234]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8ce2d'),
#   'name': 'ScienCentral',
#   'totalOffices': 1.0,
#   'lat': 40.752224,
#   'lng': -73.99211,
#   'principal': {'type': 'Point', 'coordinates': [-73.99211, 40.752224]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b965'),
#   'name': 'Undertone',
#   'totalOffices': 6.0,
#   'lat': 40.7509033,
#   'lng': -73.9779759,
#   'principal': {'type': 'Point', 'coordinates': [-73.9779759, 40.7509033]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bf23'),
#   'name': 'Pluribo',
#   'totalOffices': 1.0,
#   'lat': 40.751293,
#   'lng': -73.978887,
#   'principal': {'type': 'Point', 'coordinates': [-73.978887, 40.751293]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d279'),
#   'name': 'RavenPack',
#   'totalOffices': 2.0,
#   'lat': 40.751293,
#   'lng': -73.978887,
#   'principal': {'type': 'Point', 'coordinates': [-73.978887, 40.751293]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d724'),
#   'name': 'FinAnalytica',
#   'totalOffices': 1.0,
#   'lat': 40.751293,
#   'lng': -73.978887,
#   'principal': {'type': 'Point', 'coordinates': [-73.978887, 40.751293]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cf40'),
#   'name': 'TOMOS Software',
#   'totalOffices': 1.0,
#   'lat': 40.7504268,
#   'lng': -73.9768083,
#   'principal': {'type': 'Point', 'coordinates': [-73.9768083, 40.7504268]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cda6'),
#   'name': 'Music For Busy People',
#   'totalOffices': 1.0,
#   'lat': 40.727763,
#   'lng': -73.976169,
#   'principal': {'type': 'Point', 'coordinates': [-73.976169, 40.727763]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c08f'),
#   'name': 'StyleCard',
#   'totalOffices': 1.0,
#   'lat': 40.738137,
#   'lng': -74.0058,
#   'principal': {'type': 'Point', 'coordinates': [-74.0058, 40.738137]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bdf8'),
#   'name': 'TradingUp Online',
#   'totalOffices': 1.0,
#   'lat': 40.752404,
#   'lng': -73.992544,
#   'principal': {'type': 'Point', 'coordinates': [-73.992544, 40.752404]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b3ed'),
#   'name': 'Behance',
#   'totalOffices': 1.0,
#   'lat': 40.74406,
#   'lng': -74.004592,
#   'principal': {'type': 'Point', 'coordinates': [-74.004592, 40.74406]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b361'),
#   'name': 'Veotag',
#   'totalOffices': 1.0,
#   'lat': 40.752957,
#   'lng': -73.98546,
#   'principal': {'type': 'Point', 'coordinates': [-73.98546, 40.752957]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c649'),
#   'name': 'Coleman Research Group',
#   'totalOffices': 1.0,
#   'lat': 40.752953,
#   'lng': -73.985025,
#   'principal': {'type': 'Point', 'coordinates': [-73.985025, 40.752953]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b9e3'),
#   'name': 'Flugpo',
#   'totalOffices': 1.0,
#   'lat': 40.752898,
#   'lng': -73.990557,
#   'principal': {'type': 'Point', 'coordinates': [-73.990557, 40.752898]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b257'),
#   'name': 'Livestream',
#   'totalOffices': 1.0,
#   'lat': 40.726155,
#   'lng': -73.995625,
#   'principal': {'type': 'Point', 'coordinates': [-73.995625, 40.726155]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b3fb'),
#   'name': 'LineUpNewYork',
#   'totalOffices': 1.0,
#   'lat': 40.753202,
#   'lng': -73.986771,
#   'principal': {'type': 'Point', 'coordinates': [-73.986771, 40.753202]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8ce9d'),
#   'name': 'HR Integrations',
#   'totalOffices': 1.0,
#   'lat': 40.752078,
#   'lng': -73.994785,
#   'principal': {'type': 'Point', 'coordinates': [-73.994785, 40.752078]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b249'),
#   'name': 'Meetup',
#   'totalOffices': 1.0,
#   'lat': 40.72604,
#   'lng': -73.995722,
#   'principal': {'type': 'Point', 'coordinates': [-73.995722, 40.72604]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c3e6'),
#   'name': 'WPP',
#   'totalOffices': 2.0,
#   'lat': 40.751513,
#   'lng': -73.9779465,
#   'principal': {'type': 'Point', 'coordinates': [-73.9779465, 40.751513]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c246'),
#   'name': 'WPP',
#   'totalOffices': 2.0,
#   'lat': 40.751513,
#   'lng': -73.9779465,
#   'principal': {'type': 'Point', 'coordinates': [-73.9779465, 40.751513]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bd2a'),
#   'name': 'Epic Advertising',
#   'totalOffices': 4.0,
#   'lat': 40.753403,
#   'lng': -73.989189,
#   'principal': {'type': 'Point', 'coordinates': [-73.989189, 40.753403]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b38f'),
#   'name': 'Heavy',
#   'totalOffices': 1.0,
#   'lat': 40.753385,
#   'lng': -73.98962,
#   'principal': {'type': 'Point', 'coordinates': [-73.98962, 40.753385]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d2d5'),
#   'name': 'WiFilez',
#   'totalOffices': 1.0,
#   'lat': 40.734331,
#   'lng': -74.005661,
#   'principal': {'type': 'Point', 'coordinates': [-74.005661, 40.734331]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b5de'),
#   'name': 'yoonew',
#   'totalOffices': 1.0,
#   'lat': 40.75362,
#   'lng': -73.986557,
#   'principal': {'type': 'Point', 'coordinates': [-73.986557, 40.75362]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b74e'),
#   'name': 'Answerology',
#   'totalOffices': 1.0,
#   'lat': 40.735537,
#   'lng': -74.006179,
#   'principal': {'type': 'Point', 'coordinates': [-74.006179, 40.735537]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c4d3'),
#   'name': 'Gravityspot',
#   'totalOffices': 1.0,
#   'lat': 40.724416,
#   'lng': -73.991122,
#   'principal': {'type': 'Point', 'coordinates': [-73.991122, 40.724416]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d5d7'),
#   'name': 'Pipeline Financial Group',
#   'totalOffices': 1.0,
#   'lat': 40.7524135,
#   'lng': -73.9783331,
#   'principal': {'type': 'Point', 'coordinates': [-73.9783331, 40.7524135]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bf9b'),
#   'name': 'Bitly',
#   'totalOffices': 1.0,
#   'lat': 40.74034,
#   'lng': -74.00721,
#   'principal': {'type': 'Point', 'coordinates': [-74.00721, 40.74034]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d06f'),
#   'name': 'betaworks',
#   'totalOffices': 1.0,
#   'lat': 40.74034,
#   'lng': -74.00721,
#   'principal': {'type': 'Point', 'coordinates': [-74.00721, 40.74034]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c519'),
#   'name': 'ecomii',
#   'totalOffices': 1.0,
#   'lat': 40.743157,
#   'lng': -74.006513,
#   'principal': {'type': 'Point', 'coordinates': [-74.006513, 40.743157]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c6ac'),
#   'name': 'acerno',
#   'totalOffices': 2.0,
#   'lat': 40.751363,
#   'lng': -73.975857,
#   'principal': {'type': 'Point', 'coordinates': [-73.975857, 40.751363]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d62a'),
#   'name': 'ChallengePost',
#   'totalOffices': 1.0,
#   'lat': 40.7408042,
#   'lng': -74.00717,
#   'principal': {'type': 'Point', 'coordinates': [-74.00717, 40.7408042]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bb2d'),
#   'name': 'onebluebrick',
#   'totalOffices': 1.0,
#   'lat': 40.729286,
#   'lng': -74.002808,
#   'principal': {'type': 'Point', 'coordinates': [-74.002808, 40.729286]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cf19'),
#   'name': 'Tech Support 4 NYC',
#   'totalOffices': 1.0,
#   'lat': 40.754142,
#   'lng': -73.9883596,
#   'principal': {'type': 'Point', 'coordinates': [-73.9883596, 40.754142]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bb80'),
#   'name': 'Facilitas',
#   'totalOffices': 1.0,
#   'lat': 40.753931,
#   'lng': -73.991123,
#   'principal': {'type': 'Point', 'coordinates': [-73.991123, 40.753931]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c485'),
#   'name': 'AdSide',
#   'totalOffices': 1.0,
#   'lat': 40.753931,
#   'lng': -73.991123,
#   'principal': {'type': 'Point', 'coordinates': [-73.991123, 40.753931]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c2e5'),
#   'name': 'AdSide',
#   'totalOffices': 1.0,
#   'lat': 40.753931,
#   'lng': -73.991123,
#   'principal': {'type': 'Point', 'coordinates': [-73.991123, 40.753931]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bd4d'),
#   'name': 'Ladies Who Launch',
#   'totalOffices': 1.0,
#   'lat': 40.753877,
#   'lng': -73.991512,
#   'principal': {'type': 'Point', 'coordinates': [-73.991512, 40.753877]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b71c'),
#   'name': 'Kluster',
#   'totalOffices': 1.0,
#   'lat': 40.723652,
#   'lng': -73.985281,
#   'principal': {'type': 'Point', 'coordinates': [-73.985281, 40.723652]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d124'),
#   'name': 'TMP Directional Marketing',
#   'totalOffices': 1.0,
#   'lat': 40.7530803,
#   'lng': -73.9790822,
#   'principal': {'type': 'Point', 'coordinates': [-73.9790822, 40.7530803]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cd38'),
#   'name': 'Traiana',
#   'totalOffices': 1.0,
#   'lat': 40.752844,
#   'lng': -73.978324,
#   'principal': {'type': 'Point', 'coordinates': [-73.978324, 40.752844]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bfc5'),
#   'name': 'GigMaven',
#   'totalOffices': 1.0,
#   'lat': 40.724289,
#   'lng': -73.980587,
#   'principal': {'type': 'Point', 'coordinates': [-73.980587, 40.724289]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b3c9'),
#   'name': 'Thumbplay',
#   'totalOffices': 1.0,
#   'lat': 40.725435,
#   'lng': -73.997395,
#   'principal': {'type': 'Point', 'coordinates': [-73.997395, 40.725435]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c819'),
#   'name': 'Behind the Burner',
#   'totalOffices': 1.0,
#   'lat': 40.753918,
#   'lng': -73.981237,
#   'principal': {'type': 'Point', 'coordinates': [-73.981237, 40.753918]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b98a'),
#   'name': 'Odeo',
#   'totalOffices': 1.0,
#   'lat': 40.753918,
#   'lng': -73.981237,
#   'principal': {'type': 'Point', 'coordinates': [-73.981237, 40.753918]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c310'),
#   'name': 'Petciety',
#   'totalOffices': 1.0,
#   'lat': 40.753207,
#   'lng': -73.995886,
#   'principal': {'type': 'Point', 'coordinates': [-73.995886, 40.753207]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c4b0'),
#   'name': 'Petciety',
#   'totalOffices': 1.0,
#   'lat': 40.753207,
#   'lng': -73.995886,
#   'principal': {'type': 'Point', 'coordinates': [-73.995886, 40.753207]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b694'),
#   'name': 'GroundReport',
#   'totalOffices': 1.0,
#   'lat': 40.725568,
#   'lng': -73.998208,
#   'principal': {'type': 'Point', 'coordinates': [-73.998208, 40.725568]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bb02'),
#   'name': 'Xerpi',
#   'totalOffices': 1.0,
#   'lat': 40.725568,
#   'lng': -73.998208,
#   'principal': {'type': 'Point', 'coordinates': [-73.998208, 40.725568]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c12a'),
#   'name': 'AppNexus',
#   'totalOffices': 2.0,
#   'lat': 40.7250495,
#   'lng': -73.9970912,
#   'principal': {'type': 'Point', 'coordinates': [-73.9970912, 40.7250495]}},
# ...
#   'totalOffices': 1.0,
#   'lat': 40.775309,
#   'lng': -73.983656,
#   'principal': {'type': 'Point', 'coordinates': [-73.983656, 40.775309]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c3ea'),
#   'name': 'Producteev',
#   'totalOffices': 1.0,
#   'lat': 40.775309,
#   'lng': -73.983656,
#   'principal': {'type': 'Point', 'coordinates': [-73.983656, 40.775309]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c2c3'),
#   'name': 'Briteclick',
#   'totalOffices': 1.0,
#   'lat': 40.708093,
#   'lng': -74.01312,
#   'principal': {'type': 'Point', 'coordinates': [-74.01312, 40.708093]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c463'),
#   'name': 'Briteclick',
#   'totalOffices': 1.0,
#   'lat': 40.708093,
#   'lng': -74.01312,
#   'principal': {'type': 'Point', 'coordinates': [-74.01312, 40.708093]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bef7'),
#   'name': 'Avature',
#   'totalOffices': 1.0,
#   'lat': 40.706271,
#   'lng': -74.009242,
#   'principal': {'type': 'Point', 'coordinates': [-74.009242, 40.706271]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b3fa'),
#   'name': 'OrganizedWisdom',
#   'totalOffices': 1.0,
#   'lat': 40.775537,
#   'lng': -73.981709,
#   'principal': {'type': 'Point', 'coordinates': [-73.981709, 40.775537]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d775'),
#   'name': 'Email Data Source',
#   'totalOffices': 1.0,
#   'lat': 40.7071576,
#   'lng': -74.0121632,
#   'principal': {'type': 'Point', 'coordinates': [-74.0121632, 40.7071576]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d026'),
#   'name': 'GameChanger Media',
#   'totalOffices': 1.0,
#   'lat': 40.7078343,
#   'lng': -74.0136605,
#   'principal': {'type': 'Point', 'coordinates': [-74.0136605, 40.7078343]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d10f'),
#   'name': 'amfAR',
#   'totalOffices': 1.0,
#   'lat': 40.704708,
#   'lng': -74.005997,
#   'principal': {'type': 'Point', 'coordinates': [-74.005997, 40.704708]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b864'),
#   'name': 'Dotsub',
#   'totalOffices': 1.0,
#   'lat': 40.7680901,
#   'lng': -73.9566761,
#   'principal': {'type': 'Point', 'coordinates': [-73.9566761, 40.7680901]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c2dd'),
#   'name': 'Kidos',
#   'totalOffices': 2.0,
#   'lat': 40.768058,
#   'lng': -73.956599,
#   'principal': {'type': 'Point', 'coordinates': [-73.956599, 40.768058]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c47d'),
#   'name': 'Kidos',
#   'totalOffices': 2.0,
#   'lat': 40.768058,
#   'lng': -73.956599,
#   'principal': {'type': 'Point', 'coordinates': [-73.956599, 40.768058]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b7ba'),
#   'name': 'Origin Digital',
#   'totalOffices': 1.0,
#   'lat': 40.761979,
#   'lng': -74.026033,
#   'principal': {'type': 'Point', 'coordinates': [-74.026033, 40.761979]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b74b'),
#   'name': 'FixSor',
#   'totalOffices': 1.0,
#   'lat': 40.706527,
#   'lng': -74.011827,
#   'principal': {'type': 'Point', 'coordinates': [-74.011827, 40.706527]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8ba5b'),
#   'name': 'Fog Creek Software',
#   'totalOffices': 1.0,
#   'lat': 40.706728,
#   'lng': -74.012533,
#   'principal': {'type': 'Point', 'coordinates': [-74.012533, 40.706728]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c1ae'),
#   'name': 'Integrate',
#   'totalOffices': 4.0,
#   'lat': 40.7481039,
#   'lng': -74.0353787,
#   'principal': {'type': 'Point', 'coordinates': [-74.0353787, 40.7481039]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c34e'),
#   'name': 'Integrate',
#   'totalOffices': 4.0,
#   'lat': 40.7481039,
#   'lng': -74.0353787,
#   'principal': {'type': 'Point', 'coordinates': [-74.0353787, 40.7481039]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b378'),
#   'name': 'JumpTV',
#   'totalOffices': 1.0,
#   'lat': 40.705898,
#   'lng': -74.011398,
#   'principal': {'type': 'Point', 'coordinates': [-74.011398, 40.705898]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c5e4'),
#   'name': 'CREOpoint',
#   'totalOffices': 1.0,
#   'lat': 40.768618,
#   'lng': -73.956458,
#   'principal': {'type': 'Point', 'coordinates': [-73.956458, 40.768618]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c4c3'),
#   'name': 'Meet Now Live',
#   'totalOffices': 1.0,
#   'lat': 40.777072,
#   'lng': -73.987036,
#   'principal': {'type': 'Point', 'coordinates': [-73.987036, 40.777072]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bf4e'),
#   'name': 'Junction Networks',
#   'totalOffices': 2.0,
#   'lat': 40.705255,
#   'lng': -74.010983,
#   'principal': {'type': 'Point', 'coordinates': [-74.010983, 40.705255]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bf52'),
#   'name': 'Airtag',
#   'totalOffices': 2.0,
#   'lat': 40.704213,
#   'lng': -74.0082089,
#   'principal': {'type': 'Point', 'coordinates': [-74.0082089, 40.704213]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8ca20'),
#   'name': 'Shutterstock',
#   'totalOffices': 1.0,
#   'lat': 40.7051551,
#   'lng': -74.0115175,
#   'principal': {'type': 'Point', 'coordinates': [-74.0115175, 40.7051551]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8ce30'),
#   'name': 'MyWealth',
#   'totalOffices': 1.0,
#   'lat': 40.7038257,
#   'lng': -74.0083282,
#   'principal': {'type': 'Point', 'coordinates': [-74.0083282, 40.7038257]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cdf3'),
#   'name': 'Comodo',
#   'totalOffices': 6.0,
#   'lat': 40.726963,
#   'lng': -74.035805,
#   'principal': {'type': 'Point', 'coordinates': [-74.035805, 40.726963]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c777'),
#   'name': 'Elika Associates',
#   'totalOffices': 1.0,
#   'lat': 40.705439,
#   'lng': -74.012822,
#   'principal': {'type': 'Point', 'coordinates': [-74.012822, 40.705439]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c9fb'),
#   'name': 'SecondMarket',
#   'totalOffices': 2.0,
#   'lat': 40.705439,
#   'lng': -74.012822,
#   'principal': {'type': 'Point', 'coordinates': [-74.012822, 40.705439]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b9c0'),
#   'name': 'MediaWhiz',
#   'totalOffices': 1.0,
#   'lat': 40.704622,
#   'lng': -74.011546,
#   'principal': {'type': 'Point', 'coordinates': [-74.011546, 40.704622]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cdcd'),
#   'name': 'Executive Intermediary',
#   'totalOffices': 1.0,
#   'lat': 40.7707439,
#   'lng': -73.9569115,
#   'principal': {'type': 'Point', 'coordinates': [-73.9569115, 40.7707439]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c9f0'),
#   'name': 'Gawkk',
#   'totalOffices': 1.0,
#   'lat': 40.778635,
#   'lng': -73.984438,
#   'principal': {'type': 'Point', 'coordinates': [-73.984438, 40.778635]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c4b7'),
#   'name': 'SuiteMatch',
#   'totalOffices': 1.0,
#   'lat': 40.747005,
#   'lng': -74.039011,
#   'principal': {'type': 'Point', 'coordinates': [-74.039011, 40.747005]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c317'),
#   'name': 'SuiteMatch',
#   'totalOffices': 1.0,
#   'lat': 40.747005,
#   'lng': -74.039011,
#   'principal': {'type': 'Point', 'coordinates': [-74.039011, 40.747005]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c514'),
#   'name': 'Alwayswater',
#   'totalOffices': 1.0,
#   'lat': 40.747005,
#   'lng': -74.039011,
#   'principal': {'type': 'Point', 'coordinates': [-74.039011, 40.747005]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8ca0b'),
#   'name': 'LeadVine',
#   'totalOffices': 1.0,
#   'lat': 40.7038704,
#   'lng': -74.0138541,
#   'principal': {'type': 'Point', 'coordinates': [-74.0138541, 40.7038704]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c696'),
#   'name': 'CarZen',
#   'totalOffices': 1.0,
#   'lat': 40.76945,
#   'lng': -73.951865,
#   'principal': {'type': 'Point', 'coordinates': [-73.951865, 40.76945]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8ccea'),
#   'name': 'Empire Rehearsal Studios',
#   'totalOffices': 1.0,
#   'lat': 40.7421458,
#   'lng': -73.9331566,
#   'principal': {'type': 'Point', 'coordinates': [-73.9331566, 40.7421458]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8be33'),
#   'name': 'Sonibyte',
#   'totalOffices': 1.0,
#   'lat': 40.769466,
#   'lng': -73.950845,
#   'principal': {'type': 'Point', 'coordinates': [-73.950845, 40.769466]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d730'),
#   'name': 'Sword',
#   'totalOffices': 1.0,
#   'lat': 40.7029757,
#   'lng': -74.0143524,
#   'principal': {'type': 'Point', 'coordinates': [-74.0143524, 40.7029757]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d7ac'),
#   'name': 'Axon Solutions',
#   'totalOffices': 1.0,
#   'lat': 40.715887,
#   'lng': -74.033251,
#   'principal': {'type': 'Point', 'coordinates': [-74.033251, 40.715887]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8beed'),
#   'name': 'Neocleus',
#   'totalOffices': 1.0,
#   'lat': 40.716438,
#   'lng': -74.033872,
#   'principal': {'type': 'Point', 'coordinates': [-74.033872, 40.716438]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bfb3'),
#   'name': 'Datapipe',
#   'totalOffices': 1.0,
#   'lat': 40.71644,
#   'lng': -74.03392,
#   'principal': {'type': 'Point', 'coordinates': [-74.03392, 40.71644]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d1bd'),
#   'name': 'Healogica',
#   'totalOffices': 1.0,
#   'lat': 40.779959,
#   'lng': -73.976151,
#   'principal': {'type': 'Point', 'coordinates': [-73.976151, 40.779959]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bb6e'),
#   'name': 'WebVet',
#   'totalOffices': 1.0,
#   'lat': 40.7717776,
#   'lng': -73.9513502,
#   'principal': {'type': 'Point', 'coordinates': [-73.9513502, 40.7717776]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b488'),
#   'name': 'RayV',
#   'totalOffices': 1.0,
#   'lat': 40.781159,
#   'lng': -73.978332,
#   'principal': {'type': 'Point', 'coordinates': [-73.978332, 40.781159]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bb96'),
#   'name': 'Accoona',
#   'totalOffices': 1.0,
#   'lat': 40.716144,
#   'lng': -74.03507,
#   'principal': {'type': 'Point', 'coordinates': [-74.03507, 40.716144]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b59c'),
#   'name': 'Etsy',
#   'totalOffices': 1.0,
#   'lat': 40.694731,
#   'lng': -73.983268,
#   'principal': {'type': 'Point', 'coordinates': [-73.983268, 40.694731]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8ca67'),
#   'name': 'VectorMAX',
#   'totalOffices': 1.0,
#   'lat': 40.7172211,
#   'lng': -74.0406491,
#   'principal': {'type': 'Point', 'coordinates': [-74.0406491, 40.7172211]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8ce53'),
#   'name': 'A1-4 Electronics',
#   'totalOffices': 1.0,
#   'lat': 40.6996318,
#   'lng': -73.9514066,
#   'principal': {'type': 'Point', 'coordinates': [-73.9514066, 40.6996318]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c07e'),
#   'name': 'Overtime Media',
#   'totalOffices': 2.0,
#   'lat': 40.779947,
#   'lng': -73.953502,
#   'principal': {'type': 'Point', 'coordinates': [-73.953502, 40.779947]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8ba2d'),
#   'name': 'New York Designs',
#   'totalOffices': 1.0,
#   'lat': 40.743264,
#   'lng': -73.923427,
#   'principal': {'type': 'Point', 'coordinates': [-73.923427, 40.743264]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b6f4'),
#   'name': 'Unype',
#   'totalOffices': 1.0,
#   'lat': 40.787783,
#   'lng': -73.976413,
#   'principal': {'type': 'Point', 'coordinates': [-73.976413, 40.787783]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d39d'),
#   'name': 'Stemline Therapeutics',
#   'totalOffices': 1.0,
#   'lat': 40.7775647,
#   'lng': -73.9459335,
#   'principal': {'type': 'Point', 'coordinates': [-73.9459335, 40.7775647]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8cf56'),
#   'name': 'VideoCustomizer',
#   'totalOffices': 2.0,
#   'lat': 40.778334,
#   'lng': -73.9453758,
#   'principal': {'type': 'Point', 'coordinates': [-73.9453758, 40.778334]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bbcd'),
#   'name': 'Broadband Reports',
#   'totalOffices': 1.0,
#   'lat': 40.7825212,
#   'lng': -73.9512806,
#   'principal': {'type': 'Point', 'coordinates': [-73.9512806, 40.7825212]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d175'),
#   'name': 'Rentricity',
#   'totalOffices': 1.0,
#   'lat': 40.7917182,
#   'lng': -73.9800645,
#   'principal': {'type': 'Point', 'coordinates': [-73.9800645, 40.7917182]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d77d'),
#   'name': 'Fictionaut',
#   'totalOffices': 2.0,
#   'lat': 40.7597951,
#   'lng': -73.9161267,
#   'principal': {'type': 'Point', 'coordinates': [-73.9161267, 40.7597951]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b724'),
#   'name': 'RareShare',
#   'totalOffices': 1.0,
#   'lat': 40.794985,
#   'lng': -73.96831,
#   'principal': {'type': 'Point', 'coordinates': [-73.96831, 40.794985]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b659'),
#   'name': 'Brownstoner Media',
#   'totalOffices': 1.0,
#   'lat': 40.684257,
#   'lng': -73.961981,
#   'principal': {'type': 'Point', 'coordinates': [-73.961981, 40.684257]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b319'),
#   'name': 'Rocketboom',
#   'totalOffices': 1.0,
#   'lat': 40.797364,
#   'lng': -73.97785,
#   'principal': {'type': 'Point', 'coordinates': [-73.97785, 40.797364]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b5c6'),
#   'name': 'Orglex',
#   'totalOffices': 1.0,
#   'lat': 40.797364,
#   'lng': -73.97785,
#   'principal': {'type': 'Point', 'coordinates': [-73.97785, 40.797364]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bb7f'),
#   'name': 'College Mogul',
#   'totalOffices': 1.0,
#   'lat': 40.798345,
#   'lng': -73.963158,
#   'principal': {'type': 'Point', 'coordinates': [-73.963158, 40.798345]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b573'),
#   'name': 'Vemo',
#   'totalOffices': 1.0,
#   'lat': 40.6772802,
#   'lng': -74.0094471,
#   'principal': {'type': 'Point', 'coordinates': [-74.0094471, 40.6772802]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d573'),
#   'name': 'iNetGiant',
#   'totalOffices': 1.0,
#   'lat': 40.675234,
#   'lng': -73.971043,
#   'principal': {'type': 'Point', 'coordinates': [-73.971043, 40.675234]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d3a2'),
#   'name': 'Spurd, Inc',
#   'totalOffices': 1.0,
#   'lat': 40.675234,
#   'lng': -73.971043,
#   'principal': {'type': 'Point', 'coordinates': [-73.971043, 40.675234]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8caf6'),
#   'name': 'Princeton Premier',
#   'totalOffices': 1.0,
#   'lat': 40.7702598,
#   'lng': -73.909232,
#   'principal': {'type': 'Point', 'coordinates': [-73.909232, 40.7702598]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8bf49'),
#   'name': 'College Toolkit',
#   'totalOffices': 1.0,
#   'lat': 40.673165,
#   'lng': -73.964687,
#   'principal': {'type': 'Point', 'coordinates': [-73.964687, 40.673165]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c15b'),
#   'name': 'InChairTV',
#   'totalOffices': 1.0,
#   'lat': 40.80405,
#   'lng': -73.952833,
#   'principal': {'type': 'Point', 'coordinates': [-73.952833, 40.80405]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8d5de'),
#   'name': 'Antenna Software',
#   'totalOffices': 2.0,
#   'lat': 40.720883,
#   'lng': -74.081365,
#   'principal': {'type': 'Point', 'coordinates': [-74.081365, 40.720883]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8ba1c'),
#   'name': 'Mad Mimi',
#   'totalOffices': 1.0,
#   'lat': 40.66509,
#   'lng': -73.980306,
#   'principal': {'type': 'Point', 'coordinates': [-73.980306, 40.66509]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8b4aa'),
#   'name': 'Simpy',
#   'totalOffices': 1.0,
#   'lat': 40.6632194,
#   'lng': -73.9800645,
#   'principal': {'type': 'Point', 'coordinates': [-73.9800645, 40.6632194]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c5e6'),
#   'name': 'Global Relay',
#   'totalOffices': 1.0,
#   'lat': 40.662332,
#   'lng': -73.982629,
#   'principal': {'type': 'Point', 'coordinates': [-73.982629, 40.662332]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c994'),
#   'name': 'Dot Com Infoway',
#   'totalOffices': 3.0,
#   'lat': 40.8129335,
#   'lng': -73.9586329,
#   'principal': {'type': 'Point', 'coordinates': [-73.9586329, 40.8129335]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8ccfa'),
#   'name': 'Hyperpot',
#   'totalOffices': 1.0,
#   'lat': 40.6599808,
#   'lng': -73.9948358,
#   'principal': {'type': 'Point', 'coordinates': [-73.9948358, 40.6599808]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8baa7'),
#   'name': 'StubOrder',
#   'totalOffices': 1.0,
#   'lat': 40.660393,
#   'lng': -73.957626,
#   'principal': {'type': 'Point', 'coordinates': [-73.957626, 40.660393]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c281'),
#   'name': 'Klatcher',
#   'totalOffices': 1.0,
#   'lat': 40.822087,
#   'lng': -73.950677,
#   'principal': {'type': 'Point', 'coordinates': [-73.950677, 40.822087]}},
#  {'_id': ObjectId('61fbc8bd7a28a88c39c8c421'),
#   'name': 'Klatcher',
#   'totalOffices': 1.0,
#   'lat': 40.822087,
#   'lng': -73.950677,
#   'principal': {'type': 'Point', 'coordinates': [-73.950677, 40.822087]}}]

# %%
pd.DataFrame(find_near(park_avenue, radio)).head()
# Out:
#                         _id               name  totalOffices        lat  \
# 0  61fbc8bd7a28a88c39c8cfd9          SpaBooker           1.0  40.738567
# 1  61fbc8bd7a28a88c39c8bdb1      HealthiNation           1.0  40.739341
# 2  61fbc8bd7a28a88c39c8b999  Special Ops Media           1.0  40.737721
# 3  61fbc8bd7a28a88c39c8d62b           Mashable           1.0  40.740154
# 4  61fbc8bd7a28a88c39c8c730        Return Path           1.0  40.740207
#
#          lng                                          principal
# 0 -73.987199  {'type': 'Point', 'coordinates': [-73.987199, ...
# 1 -73.988357  {'type': 'Point', 'coordinates': [-73.988357, ...
# 2 -73.987725  {'type': 'Point', 'coordinates': [-73.987725, ...
# 3 -73.986742  {'type': 'Point', 'coordinates': [-73.9867417,...
# 4 -73.987002  {'type': 'Point', 'coordinates': [-73.987002, ...

# %%
def find_near(lst_lat_lng, radio=1000):
    
    return db.first_office.find({'principal':{
        '$near': {'$geometry': {'type': 'Point', 'coordinates':lst_lat_lng}, 
                  '$maxDistance':radio}
    }})

# %%
pd.DataFrame(find_near([-73.987308, 40.738935])).head()
# Out:
#                         _id               name  totalOffices        lat  \
# 0  61fbc8bd7a28a88c39c8cfd9          SpaBooker           1.0  40.738567
# 1  61fbc8bd7a28a88c39c8bdb1      HealthiNation           1.0  40.739341
# 2  61fbc8bd7a28a88c39c8b999  Special Ops Media           1.0  40.737721
# 3  61fbc8bd7a28a88c39c8d62b           Mashable           1.0  40.740154
# 4  61fbc8bd7a28a88c39c8c730        Return Path           1.0  40.740207
#
#          lng                                          principal
# 0 -73.987199  {'type': 'Point', 'coordinates': [-73.987199, ...
# 1 -73.988357  {'type': 'Point', 'coordinates': [-73.988357, ...
# 2 -73.987725  {'type': 'Point', 'coordinates': [-73.987725, ...
# 3 -73.986742  {'type': 'Point', 'coordinates': [-73.9867417,...
# 4 -73.987002  {'type': 'Point', 'coordinates': [-73.987002, ...

# %%
db.first_office.drop()
